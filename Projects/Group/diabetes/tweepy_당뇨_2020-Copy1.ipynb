# %% [markdown]
# # tweet crawling

# %% [markdown]
# ## 키워드 == 당뇨

# %%
pip install tweepy
# Out:
# Collecting tweepy
#   Downloading tweepy-4.10.1-py3-none-any.whl (94 kB)
#      |████████████████████████████████| 94 kB 2.2 MB/s eta 0:00:011
# Requirement already satisfied: requests<3,>=2.27.0 in /Users/MAXY/opt/anaconda3/lib/python3.9/site-packages (from tweepy) (2.27.1)
# Collecting requests-oauthlib<2,>=1.2.0
#   Using cached requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Collecting oauthlib<4,>=3.2.0
#   Using cached oauthlib-3.2.0-py3-none-any.whl (151 kB)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/MAXY/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.27.0->tweepy) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/MAXY/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.27.0->tweepy) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/MAXY/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.27.0->tweepy) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /Users/MAXY/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.27.0->tweepy) (3.3)
# Installing collected packages: oauthlib, requests-oauthlib, tweepy
# Successfully installed oauthlib-3.2.0 requests-oauthlib-1.3.1 tweepy-4.10.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import tweepy

# 트위터 API에 접근하기 위한 개인 키를 입력
consumer_key = "f5rVJHYk4ZKCKDiqdfHq7YU84"
consumer_secret = "eGYtlTB5BduWhEdQIG8qyzYhICLymfgm0pqoRUizJibXURfWMf"

access_token = "1560514368764547072-1UXDAXTGLgGxFGD7FOu1dslmWJVCUX"
access_token_secret = "iuqmwjumUjAubKaFi34zu3paodna4ZvJld0chCltZsjLz"


# OAuth 핸들러 생성 & 개인정보 인증 요청
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)

# 액세스 요청
auth.set_access_token(access_token, access_token_secret)

# api instace 생성
api = tweepy.API(auth)

# %%
pip install snscrape
# Out:
# Collecting snscrape
#   Downloading snscrape-0.4.3.20220106-py3-none-any.whl (59 kB)
# Requirement already satisfied: requests[socks] in c:\users\user\anaconda3\envs\cakd7\lib\site-packages (from snscrape) (2.27.1)
# Requirement already satisfied: pytz in c:\users\user\anaconda3\envs\cakd7\lib\site-packages (from snscrape) (2022.1)
# Collecting filelock
#   Downloading filelock-3.8.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: lxml in c:\users\user\anaconda3\envs\cakd7\lib\site-packages (from snscrape) (4.9.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\user\anaconda3\envs\cakd7\lib\site-packages (from snscrape) (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\user\anaconda3\envs\cakd7\lib\site-packages (from beautifulsoup4->snscrape) (2.3.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\user\anaconda3\envs\cakd7\lib\site-packages (from requests[socks]->snscrape) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\user\anaconda3\envs\cakd7\lib\site-packages (from requests[socks]->snscrape) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\envs\cakd7\lib\site-packages (from requests[socks]->snscrape) (2022.6.15)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\envs\cakd7\lib\site-packages (from requests[socks]->snscrape) (3.3)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\user\anaconda3\envs\cakd7\lib\site-packages (from requests[socks]->snscrape) (1.7.1)
# Installing collected packages: filelock, snscrape
# Successfully installed filelock-3.8.0 snscrape-0.4.3.20220106
# Note: you may need to restart the kernel to use updated packages.

# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd

# 트윗을 긁어와서 넣어놓을 리스트 생성
tweets_list = []

# TwitterSearchSc,ㅡ .raper를 이용하여 해당 트윗을 긁어와서 리스트에 넣기 ('검색어 since:시작날짜 until:끝나는날짜)
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('당뇨 since:2020-01-01 until:2020-12-31').get_items()):
    if i>5000:
        break
    tweets_list.append([tweet.date, tweet.content, tweet.likeCount])
    
# 다 긁어왔다면 데이터 프레임으로 저장시키기
tweets_df = pd.DataFrame(tweets_list, columns=['Datetime', 'Text', 'Like'])
tweets_df
# Out:
#                       Datetime  \
# 0    2020-12-30 22:47:13+00:00
# 1    2020-12-30 22:29:01+00:00
# 2    2020-12-30 21:53:00+00:00
# 3    2020-12-30 21:28:14+00:00
# 4    2020-12-30 19:57:30+00:00
# ...                        ...
# 4996 2020-10-12 07:00:08+00:00
# 4997 2020-10-12 05:19:26+00:00
# 4998 2020-10-12 05:17:39+00:00
# 4999 2020-10-12 05:15:43+00:00
# 5000 2020-10-12 04:53:55+00:00
#
#                                                    Text  Like
# 0     소화되고 나면 예외 없이 그 구조와 기능은 사라진다. 이런 주장은 당뇨 환자가 인슐...     0
# 1     김용민 PD 님\n잘 견디고 계시죠 ?\n\n과체중에 당뇨 도 있다 하셔서\n걱정이...     0
# 2     아무튼 비만코드에서 비만도 당뇨도 아닌 나에게 가장 take home message...     2
# 3     친정엄마도 국을 잘 안끓이시고 비비고 국종류 잔뜩 사다놓으셨는데 조미료 맛에 간도 ...     0
# 4                                      여러분 당뇨조심하세요 아시겟죠     2
# ...                                                 ...   ...
# 4996  신기한 모링가 씨앗 씨앗\nhttps://t.co/IgGckgG12C\n\n#모링가...     0
# 4997                         너무 그렇게 웃지는마,, 나 당뇨로 죽을수도있어     0
# 4998         @hints_a 여러분들 하지만 조절 잘해야해요 저 당뇨약먹고있어…이나이에…     1
# 4999                           항당뇨제 시장 꼬리칸 탑승 개발열기 “설설”     0
# 5000         당뇨와 혈압에는 뽕잎 차  : \nhttps://t.co/qh2ACM8cLy     0
#
# [5001 rows x 3 columns]

# %%
import pandas as pd

# %%
tweets_df.to_csv('tweet_diabetes_2020')

# %%
df = pd.read_csv('tweet_diabetes_2020')
df
# Out:
#       Unnamed: 0                   Datetime  \
# 0              0  2020-12-30 22:47:13+00:00
# 1              1  2020-12-30 22:29:01+00:00
# 2              2  2020-12-30 21:53:00+00:00
# 3              3  2020-12-30 21:28:14+00:00
# 4              4  2020-12-30 19:57:30+00:00
# ...          ...                        ...
# 4996        4996  2020-10-12 07:00:08+00:00
# 4997        4997  2020-10-12 05:19:26+00:00
# 4998        4998  2020-10-12 05:17:39+00:00
# 4999        4999  2020-10-12 05:15:43+00:00
# 5000        5000  2020-10-12 04:53:55+00:00
#
#                                                    Text  Like
# 0     소화되고 나면 예외 없이 그 구조와 기능은 사라진다. 이런 주장은 당뇨 환자가 인슐...     0
# 1     김용민 PD 님\n잘 견디고 계시죠 ?\n\n과체중에 당뇨 도 있다 하셔서\n걱정이...     0
# 2     아무튼 비만코드에서 비만도 당뇨도 아닌 나에게 가장 take home message...     2
# 3     친정엄마도 국을 잘 안끓이시고 비비고 국종류 잔뜩 사다놓으셨는데 조미료 맛에 간도 ...     0
# 4                                      여러분 당뇨조심하세요 아시겟죠     2
# ...                                                 ...   ...
# 4996  신기한 모링가 씨앗 씨앗\nhttps://t.co/IgGckgG12C\n\n#모링가...     0
# 4997                         너무 그렇게 웃지는마,, 나 당뇨로 죽을수도있어     0
# 4998         @hints_a 여러분들 하지만 조절 잘해야해요 저 당뇨약먹고있어…이나이에…     1
# 4999                           항당뇨제 시장 꼬리칸 탑승 개발열기 “설설”     0
# 5000         당뇨와 혈압에는 뽕잎 차  : \nhttps://t.co/qh2ACM8cLy     0
#
# [5001 rows x 4 columns]

# %%
text_data = df.Text.values
text_data
# Out:
# array(['소화되고 나면 예외 없이 그 구조와 기능은 사라진다. 이런 주장은 당뇨 환자가 인슐린(단백질) 주사가 아니라 그냥 먹어줘도 된다는 논리와 같다. 또 콜라겐을 먹어서 보충한다면 근육을 먹어 근육질이 되고 동물(뇌)골을 먹어 뇌를 좋게 한다는 주장과 뭐가 다른가 하는 거다.',
#        '김용민 PD 님\n잘 견디고 계시죠 ?\n\n과체중에 당뇨 도 있다 하셔서\n걱정이 많이 됩니다.\n\n당신을 응원하는 많은 지지자들\n을 위해 코로나를 잘 물리치시고\n빨리 제자리로 돌아오세요.',
#        '아무튼 비만코드에서 비만도 당뇨도 아닌 나에게 가장 take home message는 1일1식 (나는 보통 저녁)을 계속 해 갈 생각이고 아침이랑 점심 안먹는건 시간도 아끼고 돈도 아끼고 건강도 챙기는 짱인 방법이라는것 근데 내가 간식으로 애용하던 프로틴바는 이제 안먹기로.',
#        ..., '@hints_a 여러분들 하지만 조절 잘해야해요 저 당뇨약먹고있어…이나이에…',
#        '항당뇨제 시장 꼬리칸 탑승 개발열기 “설설”',
#        '당뇨와 혈압에는 뽕잎 차  : \nhttps://t.co/qh2ACM8cLy'], dtype=object)

# %%
data = ' '.join(text_data)
data
# Out:
# '소화되고 나면 예외 없이 그 구조와 기능은 사라진다. 이런 주장은 당뇨 환자가 인슐린(단백질) 주사가 아니라 그냥 먹어줘도 된다는 논리와 같다. 또 콜라겐을 먹어서 보충한다면 근육을 먹어 근육질이 되고 동물(뇌)골을 먹어 뇌를 좋게 한다는 주장과 뭐가 다른가 하는 거다. 김용민 PD 님\n잘 견디고 계시죠 ?\n\n과체중에 당뇨 도 있다 하셔서\n걱정이 많이 됩니다.\n\n당신을 응원하는 많은 지지자들\n을 위해 코로나를 잘 물리치시고\n빨리 제자리로 돌아오세요. 아무튼 비만코드에서 비만도 당뇨도 아닌 나에게 가장 take home message는 1일1식 (나는 보통 저녁)을 계속 해 갈 생각이고 아침이랑 점심 안먹는건 시간도 아끼고 돈도 아끼고 건강도 챙기는 짱인 방법이라는것 근데 내가 간식으로 애용하던 프로틴바는 이제 안먹기로. 친정엄마도 국을 잘 안끓이시고 비비고 국종류 잔뜩 사다놓으셨는데 조미료 맛에 간도 센거 같고.. 고혈압인 아빠가 이거 자주 드시면 건강에 안좋을거 같다. 빵&amp;과자도 설탕말고 물엿이나 몸에 안좋은 과당 맛이 진해서 당뇨있는 분들은 시판음식 못드실거 같다. 여러분 당뇨조심하세요 아시겟죠 미스아키 진짜 달다\n별안간\n당뇨로\n기절한 여성 #냠냠_기분좋게_먹을수_있는_양\n당뇨전 기준\n\n밥: 2공기\n빵: 무한정\n라면: 2~3봉지\n피자: L한판\n치킨: 한마리\n빙수: 설빙 하나뚝딱\n떡볶이: 엽떡기준 반정도\n케이크: 3조각\n토스트: 최대 7개먹어봄\n음료수: 2리터\n햄버거세트메뉴: 징거버거 2세트+치킨한조각 코코아 한잔 더 타마셔야지......... 당뇨조심해야하는데... 어자피 주말에 피검사하러가고 담주에 입원할거니까 걍 마시겠음... 딸기는 당뇨에 꽤 괜찮은 과일입니다...저희 아빠가 병원 허락 받고 드시거든요 https://t.co/y4cCTbg3Jo @plptuyis @Lev__1234 당뇨걸릴것같아서 고시키입에 버림 초콜릿 도핑하면서 겨우겨우 끝냈음 \n당뇨걸릴듯 미국여행 다시 가고싶어 가서 본토 맥앤치즈에 핫치토스 닥페에 중독되서 살
완치후엔 치료비 전액 본인부담 해야 됨 아직 모두 미지의 세계 탈모 당뇨 만성피로 브레인 포그 환청 뇌이상 등 많은 후유증이 있네 절대 야외활동 혼잡한 곳 방문 조심 코로나에 걸리지 말자 차피 할버지 당뇨땜에 못드시니 기분만 내고 내가 먹을거라 내 취향으로 사기 우리집은 제일큰게 당뇨라 왜 양쪽다 당뇨가 디폴이지 끄덕 당뇨는 걸릴것이 못되는겨 나는 유전이긴한데 고통 당뇨로입원했었는데 작년 여름인가 그게 내 여름이였어 와 밥맛없어 끄덕 최대한 입원하지말자 병원식 진짜 맛없어 당뇨식은 특히 당뇨 흐릿 당뇨식 먹는데 다시는 입원안해야지밖에 생각안들더라 저 ...

# %%
#문자 형태 분석, tag:품시
from konlpy.tag import Okt

# Okt 함수를 이용해 형태소 분석
okt = Okt()
line =[]

line = okt.pos(wf)

noun_list =[]
# 명사 또는 형용사인 단어만 noun_list에 넣어주기
for word, tag in line:
    if(tag=='Noun') & (len(word)>1):
        noun_list.append(word)
# 명사 또는 형용사인 단어 및 2글자 이상인 단어 선택 시
# n_adj = [word for word, tag in line if tag in ['Noun','Adjective'] and len(word) > 1]

#제외할 단어 추가
stop_words = "당뇨 당뇨병 네이버 블로그 때문 하나 사실 한번 시작 얘기 일단 혹시 모두 점집 비비고 이야기 세상갑자기 해도 자기 자꾸 새끼 스토리 이제 그제 박사 문제 연구 정도 우리 오늘 하루 요즘 세계 보고 정말 그거 누설 그냥 알콜 진짜 혈당 환자 입니다. 사람 생각 출처 조졌다 재기 시발 씨발 이누이 존나 각종 지금 질환 건강 박제 레이 털털 무슨 뱃맛쨩 성문 오빠 유샤녀 민주당 이재명 트윗 일부러 싸가지 쭈은듯 약간 거의 소연 카톡 난대 바로 촌장 부케 나름 옹이 골렘 거대 개인 걸렷어 얼른 의심 미미 인용 역시 아그네스 쾌남 양빠 느낌 아리마 라라 펑크 귀신 "
stop_words = set(stop_words.split(' '))
        
noun_list = [word for word in noun_list if not word in stop_words]
print(noun_list)
# Out:
# ['소화', '예외', '구조', '기능', '주장', '인슐린', '단백질', '주사', '논리', '콜라겐', '보충', '근육', '육질', '동물', '주장', '다른', '김용민', '계시', '과체중', '걱정', '당신', '응원', '지지자', '위해', '코로나', '제자리', '비만', '코드', '비만', '가장', '보통', '저녁', '계속', '아침', '점심', '시간', '방법', '간식', '애용', '프로', '틴바', '친정엄마', '종류', '잔뜩', '조미료', '간도', '고혈압', '아빠', '자주', '과자', '설탕', '물엿', '과당', '시판', '음식', '여러분', '미스', '아키', '별안간', '기절', '여성', '기분', '기준', '공기', '무한정', '라면', '봉지', '피자', '한판', '치킨', '마리', '빙수', '설빙', '뚝딱', '떡볶이', '엽떡', '기준', '반정', '케이크', '조각', '토스트', '최대', '음료수', '리터', '햄버거', '세트', '메뉴', '징거버거', '세트', '치킨', '조각', '코코아', '한잔', '어자피', '주말', '검사', '입원', '딸기', '과일', '저희', '아빠', '병원', '허락', '키입', '초콜릿
로나', '후유증', '코로나', '동안', '고통', '완치', '치료', '전액', '본인', '부담', '미지', '탈모', '만성', '피로', '브레인', '포그', '환청', '이상', '후유증', '절대', '야외', '활동', '방문', '조심', '코로나', '차피', '할버', '기분', '취향', '사기', '제일', '양쪽', '디폴', '끄덕', '유전', '고통', '입원', '작년', '여름', '그게', '여름', '밥맛', '끄덕', '최대한', '입원', '병원', '흐릿', '입원', '안해', '치토세', '프로필', '치토세', '모든', '복장', '보시', '왼쪽', '허리춤', '가방', '여기', '측정기', '설정', '아지트', '인슐린', '전용', '단어', '향톡', '엘빈', '다주', '달달', '구리', '얼마나', '노력', '이오나', '가끔', '후회', '취존이랍니', '알라', '정이', '다음', '질문', '상자', '커피', '사탕', '카페인', '중독', '멈칫', '학교', '생판', '한참', '취했', '쪼끔', '웃음', '소리', '위로', '설탕', '인생', '이유', '경계', '마찬가지', '위로', '이응준', '췌장', '동양', '췌장', '종일', '퍼스', '수치', '다시', '디저트', '부림', '액상과당', '절레절레임', '모야', '이정', '라며', '상태', '방치', '실제', '비만', '관절', '구시', '부상', '규모', '손해', '저녁', '떡볶이', '대신', '채소', '볶음', '봉봉', '해결', '친구', '서머', '박달', '휘핑', '잔뜩', '카라멜', '잔뜩', '엄마', '대한', '걱정', '최애', '공통점', '유전', '또한', '예비군', '설탕', '공장', '건강검진', '먼저', '엄마', '갑자기', '걱정', '아이스', '초코', '초콜렛', '금지', '아빠', '표정', '마자', '끼리', '실실', '대면', '달달', '성인병', '엄마', '간병', '거중', '채식', '주의', '아무', '쓸모', '채식', '탄수화물', '과일', '킬러', '지름길', '동물복지', '합리화', '채소', '과일', '자연', '파괴', '레이드', '주변', '환경', '세상', '형도', '딸기', '계피', '가루', '계피', '편강', '계피', '아주', '티스푼', '편강', '동맥경화', '혈액', '순환', '고지혈증', '우울증', '계피', '가루', '금상첨화', '머리' ...

# %%
from collections import Counter
one_word = []
for word, tag in line:
    if (tag == 'Noun') & (len(word)==1):
        one_word.append(word)
one_dict = dict(Counter(one_word).most_common())
keys = sorted(one_dict.items(), key=lambda x:x[1], reverse=True)
keys[:10]
# Out:
# [('거', 445),
#  ('나', 440),
#  ('것', 399),
#  ('저', 303),
#  ('안', 254),
#  ('내', 241),
#  ('약', 241),
#  ('때', 236),
#  ('이', 224),
#  ('더', 204)]

# %%
from collections import Counter
from matplotlib import rc
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

rc('font',family='Malgun Gothic') #한글 폰트 설정
plt.rcParams['axes.unicode_minus'] = False # 마이너스 부호 출력 설정
count = Counter(noun_list)
data = dict(count.most_common())
series = pd.Series(data)
df = pd.DataFrame(series,columns=['cnt'])
df1 = df.sort_values(by='cnt',ascending=False)[:50]
df1.reset_index(inplace=True)
df1
# Out:
#    index  cnt
# 0    고혈압  287
# 1     달달  261
# 2     걱정  172
# 3    합병증  142
# 4     관리  139
# 5     병원  138
# 6     예방  135
# 7    인슐린  132
# 8     검사  128
# 9     운동  125
# 10    위험  121
# 11    완치  119
# 12    음식  119
# 13    수치  114
# 14    비만  113
# 15    설탕  113
# 16    가족   98
# 17    혈압   87
# 18    치료   85
# 19    초코   84
# 20    사망   82
# 21    김포   81
# 22   초콜릿   80
# 23   코로나   80
# 24    가지   79
# 25    증상   79
# 26    비법   79
# 27    주사   77
# 28    이상   77
# 29    엄마   75
# 30   송문기   74
# 31    시간   71
# 32    백신   71
# 33    가능   69
# 34  건강검진   68
# 35    아빠   67
# 36    조절   64
# 37    사랑   63
# 38    식단   63
# 39  고지혈증   62
# 40    뉴스   61
# 41    커피   59
# 42    독감   59
# 43    계속   58
# 44    원인   58
# 45  스트레스   57
# 46    생활   57
# 47    의사   57
# 48    다음   57
# 49    나이   57

# %%
from wordcloud import WordCloud

plt.figure(figsize=(20,20))
wordcloud = WordCloud(font_path='./이순신돋움체.ttf',background_color='white',prefer_horizontal=1,
                     colormap='flare', width=800,max_words=100, height=600).generate_from_frequencies(data)
plt.imshow(wordcloud)
plt.axis('off')
# Out:
# (-0.5, 799.5, 599.5, -0.5)

# %%
from wordcloud import WordCloud

plt.figure(figsize=(12,10))
wordcloud = WordCloud(font_path='./이순신돋움체.ttf',background_color='white',
                     colormap='brg', width=800, height=600, max_words=100, prefer_horizontal=1).generate_from_frequencies(data)
plt.imshow(wordcloud)
plt.axis('off')
# Out:
# (-0.5, 799.5, 599.5, -0.5)

# %% [markdown]
# ## 불용어 처리 예시 코드

# %%
from konlpy.tag import Okt
from wordcloud import WordCloud
from collections import Counter

# text 파일 읽어오기
#※※주소불러올때 \를 //로 바꾸어주기※※
blog_text = open('C://주소//blog_text.txt','rt', encoding='UTF-8').read()
#print(blog_text)

# csv 파일일때
# import pandas as pd
# blog_text = pd.read_csv('csv파일.csv',encoding='utf-8')
# blog_text = blog_text['형태소분석할 컬럼명']

# Okt 함수를 이용해 형태소 분석
okt = Okt()
line =[]

line = okt.pos(blog_text)

n_adj =[]
# 명사 또는 형용사인 단어만 n_adj에 넣어주기
for word, tag in line:
    if tag in ['Noun','Adjective']:
        n_adj.append(word)
# 명사 또는 형용사인 단어 및 2글자 이상인 단어 선택 시
# n_adj = [word for word, tag in line if tag in ['Noun','Adjective'] and len(word) > 1]

#제외할 단어 추가
stop_words = "상암맛집 입니다 있어서 입니다." #추가할 때 띄어쓰기로 추가해주기
stop_words = set(stop_words.split(' '))

n_adj = [word for word in n_adj if not word in stop_words]
print(n_adj)

#print(line)
#print(n_adj)

#가장 많이 나온 단어 100개 저장
counts = Counter(n_adj)
tags = counts.most_common(100)

# 이미지 추가(워드크라우드 모양 설정)
import numpy as np
from PIL import Image

mask = Image.new("RGBA",(2555,2275), (255,255,255)) #(2555,2575)는 사진 크기, (255,255,255)는 색을의미
image = Image.open('C://Users//user//주소//heart.png').convert("RGBA")
x,y = image.size
mask.paste(image,(0,0,x,y),image)
mask = np.array(mask)

###WordCloud(워드크라우드) 만들기###
#폰트지정
font='C://폰트주소//폰트이름.ttf'
word_cloud = WordCloud(font_path=font, background_color='black',max_font_size=400, mask=mask,colormap='prism').generate_from_frequencies(dict(tags))

# 사이즈 설정 및 화면에 출력
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
plt.imshow(word_cloud)
plt.axis('off')
#워드클라우드 사진으로 저장
#cloud.to_file('상암맛집_wc.png')
#또는
plt.savefig('상암맛집.png', bbox_inches='tight')
plt.show()
