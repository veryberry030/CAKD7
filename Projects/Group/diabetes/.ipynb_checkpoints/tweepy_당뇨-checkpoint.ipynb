# %% [markdown]
# # tweet crawling

# %% [markdown]
# ## 키워드 == 당뇨

# %%
pip install tweepy
# Out:
# Requirement already satisfied: tweepy in c:\users\user\anaconda3\envs\cakd7\lib\site-packages (4.10.0)
# Requirement already satisfied: requests<3,>=2.27.0 in c:\users\user\anaconda3\envs\cakd7\lib\site-packages (from tweepy) (2.27.1)
# Requirement already satisfied: oauthlib<4,>=3.2.0 in c:\users\user\anaconda3\envs\cakd7\lib\site-packages (from tweepy) (3.2.0)
# Requirement already satisfied: requests-oauthlib<2,>=1.2.0 in c:\users\user\anaconda3\envs\cakd7\lib\site-packages (from tweepy) (1.3.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\envs\cakd7\lib\site-packages (from requests<3,>=2.27.0->tweepy) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\envs\cakd7\lib\site-packages (from requests<3,>=2.27.0->tweepy) (2022.6.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\user\anaconda3\envs\cakd7\lib\site-packages (from requests<3,>=2.27.0->tweepy) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\user\anaconda3\envs\cakd7\lib\site-packages (from requests<3,>=2.27.0->tweepy) (1.26.9)
# Note: you may need to restart the kernel to use updated packages.

# %%
import tweepy

# 트위터 API에 접근하기 위한 개인 키를 입력
consumer_key = "f5rVJHYk4ZKCKDiqdfHq7YU84"
consumer_secret = "eGYtlTB5BduWhEdQIG8qyzYhICLymfgm0pqoRUizJibXURfWMf"

access_token = "1560514368764547072-1UXDAXTGLgGxFGD7FOu1dslmWJVCUX"
access_token_secret = "iuqmwjumUjAubKaFi34zu3paodna4ZvJld0chCltZsjLz"


# OAuth 핸들러 생성 & 개인정보 인증 요청
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)

# 액세스 요청
auth.set_access_token(access_token, access_token_secret)

# api instace 생성
api = tweepy.API(auth)

# %%
pip install snscrape
# Out:
# Collecting snscrape
#   Downloading snscrape-0.4.3.20220106-py3-none-any.whl (59 kB)
# Requirement already satisfied: requests[socks] in c:\users\user\anaconda3\envs\cakd7\lib\site-packages (from snscrape) (2.27.1)
# Requirement already satisfied: pytz in c:\users\user\anaconda3\envs\cakd7\lib\site-packages (from snscrape) (2022.1)
# Collecting filelock
#   Downloading filelock-3.8.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: lxml in c:\users\user\anaconda3\envs\cakd7\lib\site-packages (from snscrape) (4.9.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\user\anaconda3\envs\cakd7\lib\site-packages (from snscrape) (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\user\anaconda3\envs\cakd7\lib\site-packages (from beautifulsoup4->snscrape) (2.3.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\user\anaconda3\envs\cakd7\lib\site-packages (from requests[socks]->snscrape) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\user\anaconda3\envs\cakd7\lib\site-packages (from requests[socks]->snscrape) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\envs\cakd7\lib\site-packages (from requests[socks]->snscrape) (2022.6.15)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\envs\cakd7\lib\site-packages (from requests[socks]->snscrape) (3.3)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\user\anaconda3\envs\cakd7\lib\site-packages (from requests[socks]->snscrape) (1.7.1)
# Installing collected packages: filelock, snscrape
# Successfully installed filelock-3.8.0 snscrape-0.4.3.20220106
# Note: you may need to restart the kernel to use updated packages.

# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd

# 트윗을 긁어와서 넣어놓을 리스트 생성
tweets_list = []

# TwitterSearchSc,ㅡ .raper를 이용하여 해당 트윗을 긁어와서 리스트에 넣기 ('검색어 since:시작날짜 until:끝나는날짜)
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('당뇨 since:2022-01-01 until:2022-08-18').get_items()):
    if i>5000:
        break
    tweets_list.append([tweet.date, tweet.content, tweet.likeCount])
    
# 다 긁어왔다면 데이터 프레임으로 저장시키기
tweets_df = pd.DataFrame(tweets_list, columns=['Datetime', 'Text', 'Like'])
tweets_df
# Out:
#                       Datetime  \
# 0    2022-08-17 23:59:13+00:00
# 1    2022-08-17 23:57:49+00:00
# 2    2022-08-17 23:56:22+00:00
# 3    2022-08-17 23:36:07+00:00
# 4    2022-08-17 23:25:50+00:00
# ...                        ...
# 4996 2022-07-19 08:17:44+00:00
# 4997 2022-07-19 08:16:10+00:00
# 4998 2022-07-19 08:16:03+00:00
# 4999 2022-07-19 08:03:56+00:00
# 5000 2022-07-19 08:02:56+00:00
#
#                                                    Text  Like
# 0     주사기랑 알콜스왑이랑 체혈침 사느라 빈털털이 돼버렷어 조졌다.... 9월 월급까지 ...     0
# 1     스윗4050은 무슨 당뇨4050아님?\n싸게싸게 재기바람 https://t.co/I...     2
# 2     설탕  먹고 싶어 요\n\n마카롱도\n타르트도!\n\n으엥 혈당조절 으엥 당뇨 ht...     0
# 3     여름에 접어들면 덥고 습하다며 축축 쳐지기 시작하다, 마트에서 아오리 발견하고 나면...     5
# 4     그리고 이제 밍 랩 시작함 ㅋㅋㅋㅋㅋ 전에 슈랑 하실 때도 한번 이러셨던 것 같은데...     0
# ...                                                 ...   ...
# 4996  연님한테 초콜릿 먹고싶다는 말 한번 잘못했다가 당뇨 걸릴정도로 많이주시는거 아닌가 싶어요     1
# 4997  ㅤㅤㅤ\n간·당뇨·심혈관에 좋은 '기적의 주스'\n\n☛  https://t.co/...     0
# 4998  메디웰 당뇨식 플러스, 30개, 200ml https://t.co/zzzd5KBVB...     0
# 4999  @spekiho47_B 사장님들\n노예에게 휴가를...\n주신다면...\n더욱더 열...     1
# 5000  당뇨 의심해야 하는 뜻밖의 증상 5 (출처 : 코메디닷컴 | 네이버 뉴스) http...     0
#
# [5001 rows x 3 columns]

# %%
import pandas as pd

# %%
tweets_df.to_csv('tweet_diabetes_2022')

# %%
df = pd.read_csv('tweet_diabetes_2022')
df
# Out:
#       Unnamed: 0                   Datetime  \
# 0              0  2022-08-17 23:59:13+00:00
# 1              1  2022-08-17 23:57:49+00:00
# 2              2  2022-08-17 23:56:22+00:00
# 3              3  2022-08-17 23:36:07+00:00
# 4              4  2022-08-17 23:25:50+00:00
# ...          ...                        ...
# 4996        4996  2022-07-19 08:17:44+00:00
# 4997        4997  2022-07-19 08:16:10+00:00
# 4998        4998  2022-07-19 08:16:03+00:00
# 4999        4999  2022-07-19 08:03:56+00:00
# 5000        5000  2022-07-19 08:02:56+00:00
#
#                                                    Text  Like
# 0     주사기랑 알콜스왑이랑 체혈침 사느라 빈털털이 돼버렷어 조졌다.... 9월 월급까지 ...     0
# 1     스윗4050은 무슨 당뇨4050아님?\n싸게싸게 재기바람 https://t.co/I...     2
# 2     설탕  먹고 싶어 요\n\n마카롱도\n타르트도!\n\n으엥 혈당조절 으엥 당뇨 ht...     0
# 3     여름에 접어들면 덥고 습하다며 축축 쳐지기 시작하다, 마트에서 아오리 발견하고 나면...     5
# 4     그리고 이제 밍 랩 시작함 ㅋㅋㅋㅋㅋ 전에 슈랑 하실 때도 한번 이러셨던 것 같은데...     0
# ...                                                 ...   ...
# 4996  연님한테 초콜릿 먹고싶다는 말 한번 잘못했다가 당뇨 걸릴정도로 많이주시는거 아닌가 싶어요     1
# 4997  ㅤㅤㅤ\n간·당뇨·심혈관에 좋은 '기적의 주스'\n\n☛  https://t.co/...     0
# 4998  메디웰 당뇨식 플러스, 30개, 200ml https://t.co/zzzd5KBVB...     0
# 4999  @spekiho47_B 사장님들\n노예에게 휴가를...\n주신다면...\n더욱더 열...     1
# 5000  당뇨 의심해야 하는 뜻밖의 증상 5 (출처 : 코메디닷컴 | 네이버 뉴스) http...     0
#
# [5001 rows x 4 columns]

# %%
text_data = df.Text.values
text_data
# Out:
# array(['주사기랑 알콜스왑이랑 체혈침 사느라 빈털털이 돼버렷어 조졌다.... 9월 월급까지 숨참아야해. 흡흡하. 흡흡하...',
#        '스윗4050은 무슨 당뇨4050아님?\n싸게싸게 재기바람 https://t.co/ISjhY15Rk9',
#        '설탕  먹고 싶어 요\n\n마카롱도\n타르트도!\n\n으엥 혈당조절 으엥 당뇨 https://t.co/rmeeYlQw63',
#        ...,
#        '메디웰 당뇨식 플러스, 30개, 200ml https://t.co/zzzd5KBVBj &lt;파트너스 활동을 통해 수수료를 제공받을 수 있음&gt; https://t.co/efZAoi5rC3',
#        '@spekiho47_B 사장님들\n노예에게 휴가를...\n주신다면...\n더욱더 열심히..\n발전하는 어쩌고...\n\n입에 뭐 넣고 있으면 안 토해서 ㄱ- 사탕 먹고 있습니다\n곧 당뇨올거같아요',
디자인의 캐릭터는 적으로 더 적절할지도 모르겠습니다 거의 처음으로 친해진 트친 얘기하다 보면 재밌는 구석이 한 두개가 아님 그녀 속에 숨어있는 유잼의 향기 숨길 수 없어 자타 보면 너무 달달해서 하루에 한 번씩 당뇨로 쓰러져요 이러다가 진짜 죽으면 어케 말투도 순둥순둥 개착해 더 많이 친해지구 싶음며 진짜 좋다 은퇴한 매버릭이 작전 끝내고 귀환한 행맨 볼 때마다 이럴 거 아니야 약간 너무 각져서 자기 취향 아니라고 일부러 설탕 넣은 팬케이크에 시럽 뿌려주면서 다 먹으라고 할 것 같음 행맨이 저 이러다 당뇨 걸리면 책임지세요 하면 매버릭은 고개 끄덕이고 그럼 행맨은 그거 다 먹음 디자인을 테크웨어냐 아님 폴아웃 마냥 서부극 클리셰의 변용을 따라가냐 고민이 된다 나 이거 ...

# %%
#문자 형태 분석, tag:품시
from konlpy.tag import Okt

# Okt 함수를 이용해 형태소 분석
okt = Okt()
line =[]

line = okt.pos(wf)

noun_list =[]
# 명사 또는 형용사인 단어만 noun_list에 넣어주기
for word, tag in line:
    if(tag=='Noun') & (len(word)>1):
        noun_list.append(word)
# 명사 또는 형용사인 단어 및 2글자 이상인 단어 선택 시
# n_adj = [word for word, tag in line if tag in ['Noun','Adjective'] and len(word) > 1]

#제외할 단어 추가
stop_words = "당뇨 당뇨병 네이버 블로그 때문 하나 사실 한번 시작 얘기 일단 혹시 모두 이야기 세상갑자기 해도 자기 자꾸 새끼 스토리 이제 그제 박사 문제 연구 정도 우리 오늘 하루 요즘 세계 보고 정말 그거 누설 그냥 알콜 진짜 혈당 환자 입니다. 사람 생각 출처 조졌다 재기 시발 씨발 이누이 존나 각종 지금 질환 건강 박제 레이 털털 무슨 뱃맛쨩 성문 오빠 유샤녀 민주당 이재명 트윗 일부러 싸가지 쭈은듯 약간 거의 소연 카톡 난대 바로 촌장 부케 나름 옹이 골렘 거대 개인 걸렷어 얼른 의심 미미 인용 역시 아그네스 쾌남 양빠 느낌 아리마 라라 펑크 귀신 "
stop_words = set(stop_words.split(' '))
        
noun_list = [word for word in noun_list if not word in stop_words]
print(noun_list)
# Out:
# ['주사기', '스왑', '체혈침', '돼버렷어', '월급', '스윗', '바람', '설탕', '마카롱', '타르트', '조절', '여름', '마트', '오리', '발견', '텐션', '배변', '활동', '혈관', '대사성', '뉴욕', '아메리카', '뉴욕', '패밀리', '장악', '루치아노', '보체', '티후', '치아노', '건강악화', '오늘내일', '혈압', '과천', '합병증', '계속', '고혈압', '미래', '거구', '디핑님', '한마디', '센스', '흐흐', '불리', '흐흐', '유전', '취약', '동양인', '북미', '식생활', '세상', '빨대', '장사', '하든', '설탕', '안보', '이면', '급성', '가즈', '가지', '관리', '방법', '고혈압', '뇌경색', '아토피', '비염', '디스크', '콜레스테롤', '피부염', '종질', '원인', '머리', '공급', '암치료', '모발', '모발', '정맥', '동맥', '저서', '모발', '모발', '정맥', '동맥', '소금', '고혈압', '먼저', '먼저', '번만', '생활', '패턴', '유지', '오십', '수야', '고혈압', '고생', '고생', '다이어트', '피자', '방법', '갱년기', '염소', '영양', '방송', '덕캐', '발언', '머랭', '쿠키', '남자', '나쁜남자', '헛소리', '치가', '의미', '머랭', '쿠키', '해죽', '질투', '달달', '머랭', '쿠키', '년도', '실비', '가입', '얼마', '재계약', '재계약', '거절', '수도', '건가', '간수치', '정상', '공복', '부터', '요새', '관리', '다시', '주사', '절제', '수술', '권유', '초고', '비만', '요새', '청년', '일찍', '자기혐오', '제출', '나때', '일주', '하라', '쓴맛', '효능', '푸드', '최초', '기록', '기원전', '거슬러', '시기', '이집트', '에베르', '파피루스', '증세', '치료', '여러가지', '방법', '대한', '최초', '기록', '추측', '오지', '지리', '얼굴', '복지', '덕질', '면서', '인생', '공감', '하루하루', '얼마나', '영상', '분만', '인생', '쓴맛', '존재', '남자', '감자', '콜레스테롤', '수치', '조절', '효과', '블랙', '망고', '수박', '변비', '예방', '적당량', '청사', '소화', '혈관', '자색', '당근', '주목', '기능', '향상', '염증', '억제', '이색', '농산물', '컬러풀', '망고', '수박', '감자', '순간', '원더풀', '물이', '쭉쭉', '웅니', '스윗', '아기', '햄스터', '트친소', '본인', '카코', '빌런', '피해자', '스텝', '경찰', '현재', '개구리', '위치', '취미', '트위치', '방송', '인생', '오늘이', '제일', '레전드', '심지어', '초기', '아현', '매장', '구매', '위트', '니스', '어우', '마비', '등분', '신부', '안함', '금단', '증세', '잠시', '경우', '꽃차', '과일', '혈액', '순환', '과일', '지도', '동생', '내지', '송문기', '완치', '비법', '손발', '이유', '미세', '혈관', '파괴', '손발', '지져스', '충격', '지방', '음식', '독소', '위험', '모든', '기름', '멀리', '닭다리', '껍질', '독소', '상분', '벌꿀', '토키', '아저씨', '아저씨', '인생', '중년', '여성', '자가', '테스트', '남편', '갑자기', '백내장', '남편', '애교', '목소리', '갑상선', '남편', '달달', '커피', '화환', '위로', '설탕', '인생', '이유', '경계', '마찬가지', '위로', '이응준', '위로', '공짜', '텐션', '마이너스', '수명', '수명', '폭언', '여기', '크로와상', '존맛', '최애', '카야', '크로와상', '스트레이트', '의식', '자제', '중임', '여름', '모양', '트레블', '고혈압', '동맥경화', '통수', '수도', '소망', '리기', '머리', '달달', '토키', '병원', '유산균', '오메가', '크로뮴', '히알루론산', '켈프', '유산균', '별로', '효과', '다른', '유산균', '콜린', '이노시톨', '간이', '인슐린', '저항', '유전자', '관련', '염려', '조심', '염주', '달달', '계속', '로만', '러닝', '염주', '어카', '걱정', '전조', '증상', '저런', '가사', '노래', '추천', '능거임', '내시경', '오백', '태세', '전환', '잡범', '말랑이', '공식', '하달', '사진', '티아', '의료', '보험', '마술사', '마저', '먹음', '사이버펑크', '분위기', '배경', '비주', '패션', '비주', '블레이드', '러너', '다시', '거유', '한안', '이퀼리브리엄', '처럼', '경직', '제복', '킬링', '머신', '소시민', '총잡이', '이퀼리브리엄', '비주', '디자인', '캐릭터', '처음', '트친', '구석', '그녀', '유잼', '향기', '자타', '달달', '어케', '말투', '순둥순둥', '은퇴', '매버릭', '작전', '귀환', '행맨', '취향', '설탕', '팬케이크', '시럽', '행맨', '매버릭', '고개', '끄덕', '행맨', '먹음', '디자인', '테크', '웨어', '폴아웃', '마냥', '서부', '클리셰', '변용', '고민', '고유', '피구', '깨알', '영양성분', '무엇', '판매', '음료', '호불호', '고살', '와인', '바디', '조음', '하이', '조음', '소주', '토닉', '워터', '마심', '우유', '우유', '킬런', '지방', '노력', '식혜', '먹음', '주스', '커피', '아아', '라떼', '탄산수', '탄산', '탄산음료', '제로', '이번', '칠성', '사이다', '플러스', '리지', '제일', '질끈', '일찍', '카코', '카드', '려고', '어우', '다행', '퇴근', '일터', '다행', '직알', '도넛', '서안', '원시천존', '언급', '빌런', '피해자', '순창군', '캠프', '송문기', '완치', '비법', '하이웨이', '운동', '방법', '체중감량', '근육', '추가', '내과', '검사', '결과', '축하', '축하', '떡볶이', '튀김', '매일', '일도', '빈둥대', '예비군', '주정뱅이', '도박중독', '반지', '뭔들', '히지카타', '형편', '모근', '머리', '크림브륄레', '그게', '식이', '조절', '직행', '식이', '조절', '고민', '카코', '검색', '도난', '안거', '초기', '증상', '가지', '완벽', '정리', '퇴근', '회수', '루시드', '너희', '작년', '처리', '사과', '사과', '손절', '딸기', '누텔라', '와플', '바나나', '누텔라', '누텔라', '암살', '시도', '여러분', '안심', '강아지', '현재', '상황', '위기', '주의', '계란말이', '갑자기', '누구', '타오', '커마', '복장', '머리스타일', '커마', '제한', '요소', '어이', '완전', '계란말이', '일주일', '이상은', '주의', '초과', '게다가', '백미', '그다음', '아이스크림', '정택필씨', '심부름', '붕어싸만코', '찰옥수수', '렵다', '거사', '맛임', '나메', '목소리', '달달', '알반', '스윗', '대장', '혈관', '대신', '자두', '주스', '그래그래', '디저트', '식사', '일상생활', '만날', '대부분', '음식', '올린다', '심지어', '그다지', '당분', '장량', '차지', '밀크', '무지', '추가', '과거', '뿐더러', '간다', '생로병사', ' ...

# %%
from collections import Counter
one_word = []
for word, tag in line:
    if (tag == 'Noun') & (len(word)==1):
        one_word.append(word)
one_dict = dict(Counter(one_word).most_common())
keys = sorted(one_dict.items(), key=lambda x:x[1], reverse=True)
keys[:10]
# Out:
# [('거', 407),
#  ('나', 399),
#  ('것', 366),
#  ('안', 263),
#  ('저', 250),
#  ('때', 224),
#  ('내', 214),
#  ('이', 210),
#  ('더', 196),
#  ('밥', 186)]

# %%
from collections import Counter
from matplotlib import rc
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

rc('font',family='Malgun Gothic') #한글 폰트 설정
plt.rcParams['axes.unicode_minus'] = False # 마이너스 부호 출력 설정
count = Counter(noun_list)
data = dict(count.most_common())
series = pd.Series(data)
df = pd.DataFrame(series,columns=['cnt'])
df1 = df.sort_values(by='cnt',ascending=False)[:50]
df1.reset_index(inplace=True)
df1
# Out:
#    index  cnt
# 0    고혈압  247
# 1     관리  219
# 2     걱정  187
# 3     달달  179
# 4     운동  133
# 5     설탕  126
# 6     위험  117
# 7     치료  113
# 8     음식  112
# 9     병원  110
# 10    효능  102
# 11    푸드   97
# 12    검사   95
# 13    효과   94
# 14    예방   91
# 15    수치   89
# 16    증상   84
# 17    식단   84
# 18    시간   84
# 19    엄마   83
# 20    가족   81
# 21    제로   80
# 22    보험   79
# 23    방송   79
# 24   합병증   78
# 25    조절   77
# 26   인슐린   76
# 27    가지   74
# 28    커피   74
# 29    쓴맛   72
# 30    초코   72
# 31    걷기   72
# 32  상황버섯   71
# 33    혈압   70
# 34    영양   67
# 35    완치   66
# 36    비만   65
# 37    음료   65
# 38  다이어트   64
# 39   갱년기   61
# 40    염소   61
# 41  고지혈증   59
# 42    비법   57
# 43    스윗   55
# 44    아침   55
# 45    나이   54
# 46    공복   53
# 47    임신   53
# 48    만성   53
# 49   송문기   52

# %%
from wordcloud import WordCloud

plt.figure(figsize=(20,20))
wordcloud = WordCloud(font_path='../Visualization/dataset/malgun.ttf',background_color='white',
                     colormap='flare', width=1500, height=1000).generate_from_frequencies(data)
plt.imshow(wordcloud)
plt.axis('off')
# Out:
# (-0.5, 1499.5, 999.5, -0.5)

# %%
from wordcloud import WordCloud

plt.figure(figsize=(12,10))
wordcloud = WordCloud(font_path='../Visualization/dataset/malgun.ttf',background_color='white',
                     colormap='brg', width=800, height=600, max_words=100, prefer_horizontal=1).generate_from_frequencies(data)
plt.imshow(wordcloud)
plt.axis('off')
# Out:
# (-0.5, 799.5, 599.5, -0.5)

# %% [markdown]
# ## 불용어 처리 예시 코드

# %%
from konlpy.tag import Okt
from wordcloud import WordCloud
from collections import Counter

# text 파일 읽어오기
#※※주소불러올때 \를 //로 바꾸어주기※※
blog_text = open('C://주소//blog_text.txt','rt', encoding='UTF-8').read()
#print(blog_text)

# csv 파일일때
# import pandas as pd
# blog_text = pd.read_csv('csv파일.csv',encoding='utf-8')
# blog_text = blog_text['형태소분석할 컬럼명']

# Okt 함수를 이용해 형태소 분석
okt = Okt()
line =[]

line = okt.pos(blog_text)

n_adj =[]
# 명사 또는 형용사인 단어만 n_adj에 넣어주기
for word, tag in line:
    if tag in ['Noun','Adjective']:
        n_adj.append(word)
# 명사 또는 형용사인 단어 및 2글자 이상인 단어 선택 시
# n_adj = [word for word, tag in line if tag in ['Noun','Adjective'] and len(word) > 1]

#제외할 단어 추가
stop_words = "상암맛집 입니다 있어서 입니다." #추가할 때 띄어쓰기로 추가해주기
stop_words = set(stop_words.split(' '))

n_adj = [word for word in n_adj if not word in stop_words]
print(n_adj)

#print(line)
#print(n_adj)

#가장 많이 나온 단어 100개 저장
counts = Counter(n_adj)
tags = counts.most_common(100)

# 이미지 추가(워드크라우드 모양 설정)
import numpy as np
from PIL import Image

mask = Image.new("RGBA",(2555,2275), (255,255,255)) #(2555,2575)는 사진 크기, (255,255,255)는 색을의미
image = Image.open('C://Users//user//주소//heart.png').convert("RGBA")
x,y = image.size
mask.paste(image,(0,0,x,y),image)
mask = np.array(mask)

###WordCloud(워드크라우드) 만들기###
#폰트지정
font='C://폰트주소//폰트이름.ttf'
word_cloud = WordCloud(font_path=font, background_color='black',max_font_size=400, mask=mask,colormap='prism').generate_from_frequencies(dict(tags))

# 사이즈 설정 및 화면에 출력
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
plt.imshow(word_cloud)
plt.axis('off')
#워드클라우드 사진으로 저장
#cloud.to_file('상암맛집_wc.png')
#또는
plt.savefig('상암맛집.png', bbox_inches='tight')
plt.show()
