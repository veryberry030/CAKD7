# %% [markdown]
# # tweet crawling

# %% [markdown]
# ## 키워드 == 당뇨

# %%
pip install tweepy
# Out:
# Collecting tweepy
#   Downloading tweepy-4.10.1-py3-none-any.whl (94 kB)
#      |████████████████████████████████| 94 kB 2.2 MB/s eta 0:00:011
# Requirement already satisfied: requests<3,>=2.27.0 in /Users/MAXY/opt/anaconda3/lib/python3.9/site-packages (from tweepy) (2.27.1)
# Collecting requests-oauthlib<2,>=1.2.0
#   Using cached requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Collecting oauthlib<4,>=3.2.0
#   Using cached oauthlib-3.2.0-py3-none-any.whl (151 kB)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/MAXY/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.27.0->tweepy) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/MAXY/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.27.0->tweepy) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/MAXY/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.27.0->tweepy) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /Users/MAXY/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.27.0->tweepy) (3.3)
# Installing collected packages: oauthlib, requests-oauthlib, tweepy
# Successfully installed oauthlib-3.2.0 requests-oauthlib-1.3.1 tweepy-4.10.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import tweepy

# 트위터 API에 접근하기 위한 개인 키를 입력
consumer_key = "f5rVJHYk4ZKCKDiqdfHq7YU84"
consumer_secret = "eGYtlTB5BduWhEdQIG8qyzYhICLymfgm0pqoRUizJibXURfWMf"

access_token = "1560514368764547072-1UXDAXTGLgGxFGD7FOu1dslmWJVCUX"
access_token_secret = "iuqmwjumUjAubKaFi34zu3paodna4ZvJld0chCltZsjLz"


# OAuth 핸들러 생성 & 개인정보 인증 요청
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)

# 액세스 요청
auth.set_access_token(access_token, access_token_secret)

# api instace 생성
api = tweepy.API(auth)

# %%
pip install snscrape
# Out:
# Collecting snscrape
#   Downloading snscrape-0.4.3.20220106-py3-none-any.whl (59 kB)
# Requirement already satisfied: requests[socks] in c:\users\user\anaconda3\envs\cakd7\lib\site-packages (from snscrape) (2.27.1)
# Requirement already satisfied: pytz in c:\users\user\anaconda3\envs\cakd7\lib\site-packages (from snscrape) (2022.1)
# Collecting filelock
#   Downloading filelock-3.8.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: lxml in c:\users\user\anaconda3\envs\cakd7\lib\site-packages (from snscrape) (4.9.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\user\anaconda3\envs\cakd7\lib\site-packages (from snscrape) (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\user\anaconda3\envs\cakd7\lib\site-packages (from beautifulsoup4->snscrape) (2.3.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\user\anaconda3\envs\cakd7\lib\site-packages (from requests[socks]->snscrape) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\user\anaconda3\envs\cakd7\lib\site-packages (from requests[socks]->snscrape) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\envs\cakd7\lib\site-packages (from requests[socks]->snscrape) (2022.6.15)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\envs\cakd7\lib\site-packages (from requests[socks]->snscrape) (3.3)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\user\anaconda3\envs\cakd7\lib\site-packages (from requests[socks]->snscrape) (1.7.1)
# Installing collected packages: filelock, snscrape
# Successfully installed filelock-3.8.0 snscrape-0.4.3.20220106
# Note: you may need to restart the kernel to use updated packages.

# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd

# 트윗을 긁어와서 넣어놓을 리스트 생성
tweets_list = []

# TwitterSearchSc,ㅡ .raper를 이용하여 해당 트윗을 긁어와서 리스트에 넣기 ('검색어 since:시작날짜 until:끝나는날짜)
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('당뇨 since:2021-01-01 until:2021-12-31').get_items()):
    if i>5000:
        break
    tweets_list.append([tweet.date, tweet.content, tweet.likeCount])
    
# 다 긁어왔다면 데이터 프레임으로 저장시키기
tweets_df = pd.DataFrame(tweets_list, columns=['Datetime', 'Text', 'Like'])
tweets_df
# Out:
#                       Datetime  \
# 0    2021-12-30 23:25:23+00:00
# 1    2021-12-30 23:19:15+00:00
# 2    2021-12-30 23:18:54+00:00
# 3    2021-12-30 23:16:11+00:00
# 4    2021-12-30 22:56:50+00:00
# ...                        ...
# 4996 2021-11-09 11:04:10+00:00
# 4997 2021-11-09 10:54:08+00:00
# 4998 2021-11-09 10:35:05+00:00
# 4999 2021-11-09 10:17:58+00:00
# 5000 2021-11-09 10:14:07+00:00
#
#                                                    Text  Like
# 0              그렇게 물어놓고 세뇨르 한 번 해봐요 누구든 당뇨 올라서 쓰러지긴 하겠다     0
# 1                                  건강악화라고 적은이유는 당뇨때문입니다     0
# 2                                  건강악화라고 적은이유는 당뇨때문입니다     0
# 3     수면 부족이 청력 저하에 영향을 미친다는 것을 동물실험을 통해 최초 규명했다고 한다...     1
# 4     롤브라인더 안양방음 카포전 당뇨환자커피 개별포장지 햇반흰쌀죽 회전원통실험 복실쓰 태...     0
# ...                                                 ...   ...
# 4996                            이렇게 단것만 수혈하다간 당뇨걸릴듯,_,)     1
# 4997  @:카렌 여관에서 밥먹고 위기감을 느꼈어요. 이제 슌이랑 할아버지 한동안 꼼짝없이 ...     0
# 4998  안볶은양파,안볶은자주색양파는\n당뇨에 안좋다 당뇨가 재발한단다\n그예로는 흑염소를 ...     0
# 4999  난 싸구려 사탕 초콜릿도 너무 좋아해서 간식 깨작거리는 습관 못 버려서 이렇게 됐는...     0
# 5000          히밸 당뇨온다\nhttps://t.co/wwoHUdMYk8 #postype     0
#
# [5001 rows x 3 columns]

# %%
import pandas as pd

# %%
tweets_df.to_csv('tweet_diabetes_2021')

# %%
df = pd.read_csv('tweet_diabetes_2021')
df
# Out:
#       Unnamed: 0                   Datetime  \
# 0              0  2021-12-30 23:25:23+00:00
# 1              1  2021-12-30 23:19:15+00:00
# 2              2  2021-12-30 23:18:54+00:00
# 3              3  2021-12-30 23:16:11+00:00
# 4              4  2021-12-30 22:56:50+00:00
# ...          ...                        ...
# 4996        4996  2021-11-09 11:04:10+00:00
# 4997        4997  2021-11-09 10:54:08+00:00
# 4998        4998  2021-11-09 10:35:05+00:00
# 4999        4999  2021-11-09 10:17:58+00:00
# 5000        5000  2021-11-09 10:14:07+00:00
#
#                                                    Text  Like
# 0              그렇게 물어놓고 세뇨르 한 번 해봐요 누구든 당뇨 올라서 쓰러지긴 하겠다     0
# 1                                  건강악화라고 적은이유는 당뇨때문입니다     0
# 2                                  건강악화라고 적은이유는 당뇨때문입니다     0
# 3     수면 부족이 청력 저하에 영향을 미친다는 것을 동물실험을 통해 최초 규명했다고 한다...     1
# 4     롤브라인더 안양방음 카포전 당뇨환자커피 개별포장지 햇반흰쌀죽 회전원통실험 복실쓰 태...     0
# ...                                                 ...   ...
# 4996                            이렇게 단것만 수혈하다간 당뇨걸릴듯,_,)     1
# 4997  @:카렌 여관에서 밥먹고 위기감을 느꼈어요. 이제 슌이랑 할아버지 한동안 꼼짝없이 ...     0
# 4998  안볶은양파,안볶은자주색양파는\n당뇨에 안좋다 당뇨가 재발한단다\n그예로는 흑염소를 ...     0
# 4999  난 싸구려 사탕 초콜릿도 너무 좋아해서 간식 깨작거리는 습관 못 버려서 이렇게 됐는...     0
# 5000          히밸 당뇨온다\nhttps://t.co/wwoHUdMYk8 #postype     0
#
# [5001 rows x 4 columns]

# %%
text_data = df.Text.values
text_data
# Out:
# array(['그렇게 물어놓고 세뇨르 한 번 해봐요 누구든 당뇨 올라서 쓰러지긴 하겠다', '건강악화라고 적은이유는 당뇨때문입니다',
#        '건강악화라고 적은이유는 당뇨때문입니다', ...,
#        '안볶은양파,안볶은자주색양파는\n당뇨에 안좋다 당뇨가 재발한단다\n그예로는 흑염소를 그것들과\n같이 섭취시 당뇨에 걸린단다',
#        '난 싸구려 사탕 초콜릿도 너무 좋아해서 간식 깨작거리는 습관 못 버려서 이렇게 됐는데🥲🥲🥲🥲 어렸을때부터 맛있는 어른간식 먹으면 당뇨나 고 콜레스테롤혈증 걸릴 것 같아서 내가 다 걱정돼',
#        '히밸 당뇨온다\nhttps://t.co/wwoHUdMYk8 #postype'], dtype=object)

# %%
data = ' '.join(text_data)
data
# Out:
서 어케 혈당검사하고 관리좀할게 및힌 굳이 시간상관없이 자다중간에 깨면 혈당 한번 확인하는게 좋음 다음다뇨다식이 당뇨 증세라서 평소에 화장실 자주가거나 계속 목마르거나 하면 가능성있음 살빠지는건 그냥많이먹으면 체중 그대로일수있음 요즘 덕질이 너무 행복해 너무 달달해서 당뇨걸릴 것 같음 야간 시간은 체내 혈당을 낮추어 주기 때문에 고혈압과 당뇨환자가 운동하기에 좋은 시간대입니다 당뇨 진단 후 금지 혹은 자제 권유 받은 항목 정제된 탄수화물 음료류 기름진 음식 동물성 지방 당질이 높은 채소류 채소 흰살 육류 생선 견과류 아메리카노 잡곡을 기반으로 저염 저지방 고식이섬유 식단 하시고 과일도 쉽게 못 먹어요 그리고 금주임 술 끊으셔야함 니 당뇨조심해라 보기만 해도 당뇨 온다 진짜 당뇨연습생은 어떻게고쳐 저는 커피도 못마셔서 아아를  ...

# %%
#문자 형태 분석, tag:품시
from konlpy.tag import Okt

# Okt 함수를 이용해 형태소 분석
okt = Okt()
line =[]

line = okt.pos(wf)

noun_list =[]
# 명사 또는 형용사인 단어만 noun_list에 넣어주기
for word, tag in line:
    if(tag=='Noun') & (len(word)>1):
        noun_list.append(word)
# 명사 또는 형용사인 단어 및 2글자 이상인 단어 선택 시
# n_adj = [word for word, tag in line if tag in ['Noun','Adjective'] and len(word) > 1]

#제외할 단어 추가
stop_words = "당뇨 당뇨병 네이버 블로그 때문 하나 사실 한번 시작 얘기 일단 혹시 모두 이야기 세상갑자기 해도 자기 자꾸 새끼 스토리 이제 그제 박사 문제 연구 정도 우리 오늘 하루 요즘 세계 보고 정말 그거 누설 그냥 알콜 진짜 혈당 환자 입니다. 사람 생각 출처 조졌다 재기 시발 씨발 이누이 존나 각종 지금 질환 건강 박제 레이 털털 무슨 뱃맛쨩 성문 오빠 유샤녀 민주당 이재명 트윗 일부러 싸가지 쭈은듯 약간 거의 소연 카톡 난대 바로 촌장 부케 나름 옹이 골렘 거대 개인 걸렷어 얼른 의심 미미 인용 역시 아그네스 쾌남 양빠 느낌 아리마 라라 펑크 귀신 "
stop_words = set(stop_words.split(' '))
        
noun_list = [word for word in noun_list if not word in stop_words]
print(noun_list)
# Out:
# ['세뇨', '누구', '건강악화', '이유', '건강악화', '이유', '수면', '부족', '청력', '저하', '영향', '동물실험', '통해', '최초', '규명', '또한', '수면', '부족', '심혈관계', '고혈압', '비만', '고지혈증', '위험', '원인', '아내', '브라', '안양', '방음', '포전', '커피', '개별', '포장', '햇반', '쌀죽', '회전', '원통', '실험', '복실', '태양전지', '키트', '플랜', '아웃', '맥스', '캠웍스', '펌로', '우즈', '일체', '수냉', '캠핑', '난로', '대여', '송문기', '완치', '비법', '헬스', '뉴스', '이상', '치하', '치주염', '심뇌', '혈관', '위험', '머리', '슈가', '이유', '일로', '상태', '고혈압', '위험', '판정', '김벨', '햄버거', '햄버거', '만들기', '보건', '지소', '고혈압', '대상', '치매', '예방', '강의', '오전', '피부', '친구', '이브', '파티', '마쓰
계', '관리', '제대로', '측정', '동시', '스스로', '인슐린', '투여', '적정', '수준', '관리', '여기', '데이터', '기반', '중심', '질병', '관리', '체계', '엄마', '개발자', '우회', '김미영', '대표', '소프트웨어', '개발자', '모토로라', '코리아', '피처폰', '일정', '관리', '소프트웨어', '개발자', '아이', '갑작스레', '진단', '유전', '이유나', '식이', '습관', '조절', '자가면역질환', '바이러스', '감염', '이유', '인슐린', '분비', '발병', '요인', '소아당뇨', '구경이', '드라마', '대사', '내용', '크게', '애가', '소아당뇨', '병원', '이후', '드라마', '마지막', '소아당뇨', '공식', '정정', '세트', '세뇨', '누구', '고구마', '맛탕', '고급', '버전', '설탕', '코팅', '다음', '연유', '무려', '취재', '상하이', '벨라지오', '평택', '꽃꽂이', '끗발', '원어민', '인강', '손실', '예방', '다카', '수입', '그릇', '윈터스', '정화조', '박스', '미립', '포기', '고유', '고온', '장갑', '복숭아', '제공', '오락', '투어', '어머니', '카페', '부자', '찰랑', '파티션', '수납', '친구', '예전', '술친구', '말임', '가슴', '병원', '즉사', '아내', '달맞이꽃', '채취', '할아버지', '본인', '채취', '방앗간', '아주', '제품', '걷기', '트친', '혈압', '가끔', '새벽', '걷기', '도움', '시간', '걷기', '혈압', '도움', '실제', '습관', '사냥개', '용품', '소원면', '펜션', '품질', '컬러', '볼펜', '변기', '비대', '수원', '무한리필', '브러쉬', '유아', '논문', '양식', '장수', '백숙', '맛집', '티비', '액정', '교체', '엄마', '파업', '직면', '인절미', '은근', '일만', '세자', '저하', '외숙모', '할아버지', '치매', '거동', '불편', '발가락', '내성발톱', '발라드', '소독', '크게', '염증', '부어', '예전', '백내장', '대가', '전자기기', '사용', '대도', '고혈압', '해당', '아토피', '원인', '주문', '잘못', '맥스', '크기', '동양인', '발병', '서양인', '현저', '수치', '가장', '기준', '요구', '녀석', '고기', '선지', '쇼크', '오지', '해결', '다시', '인육', '사냥', '호영', '타점', '고화질', '영아', '설탕', '음식', '마음', '소아', '백신', '패스', '백신', '사경', '조금',  ...

# %%
from collections import Counter
one_word = []
for word, tag in line:
    if (tag == 'Noun') & (len(word)==1):
        one_word.append(word)
one_dict = dict(Counter(one_word).most_common())
keys = sorted(one_dict.items(), key=lambda x:x[1], reverse=True)
keys[:10]
# Out:
# [('거', 434),
#  ('것', 422),
#  ('나', 417),
#  ('때', 269),
#  ('저', 250),
#  ('안', 247),
#  ('내', 227),
#  ('이', 211),
#  ('밥', 201),
#  ('더', 196)]

# %%
from collections import Counter
from matplotlib import rc
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

rc('font',family='Malgun Gothic') #한글 폰트 설정
plt.rcParams['axes.unicode_minus'] = False # 마이너스 부호 출력 설정
count = Counter(noun_list)
data = dict(count.most_common())
series = pd.Series(data)
df = pd.DataFrame(series,columns=['cnt'])
df1 = df.sort_values(by='cnt',ascending=False)[:50]
df1.reset_index(inplace=True)
df1
# Out:
#    index  cnt
# 0    고혈압  247
# 1     달달  189
# 2     걱정  178
# 3     예방  167
# 4     관리  164
# 5     검사  147
# 6     운동  143
# 7     병원  129
# 8     설탕  126
# 9     수치  126
# 10    위험  123
# 11    식단  112
# 12    음식  103
# 13    초코  103
# 14    가족  102
# 15    콜라   98
# 16    백신   92
# 17    치료   91
# 18   합병증   85
# 19    엄마   84
# 20    시간   83
# 21    과일   83
# 22    현상   82
# 23   인슐린   81
# 24    이상   78
# 25   초콜릿   77
# 26    혈압   77
# 27    아침   77
# 28    완치   73
# 29    원인   72
# 30    커피   71
# 31    조절   69
# 32    제로   69
# 33    증상   69
# 34   케이크   69
# 35    정상   66
# 36    계속   65
# 37    가지   65
# 38    친구   63
# 39    사랑   62
# 40    나이   60
# 41    결과   60
# 42    스윗   58
# 43    다시   57
# 44    공복   57
# 45   송문기   56
# 46    비법   56
# 47    단맛   55
# 48    비만   55
# 49    뉴스   54

# %%
from wordcloud import WordCloud

plt.figure(figsize=(20,20))
wordcloud = WordCloud(font_path='./이순신돋움체.ttf',background_color='white',prefer_horizontal=1,
                     colormap='flare', width=800,max_words=100, height=600).generate_from_frequencies(data)
plt.imshow(wordcloud)
plt.axis('off')
# Out:
# (-0.5, 799.5, 599.5, -0.5)

# %%
from wordcloud import WordCloud

plt.figure(figsize=(12,10))
wordcloud = WordCloud(font_path='./이순신돋움체.ttf',background_color='white',
                     colormap='brg', width=800, height=600, max_words=100, prefer_horizontal=1).generate_from_frequencies(data)
plt.imshow(wordcloud)
plt.axis('off')
# Out:
# (-0.5, 799.5, 599.5, -0.5)

# %% [markdown]
# ## 불용어 처리 예시 코드

# %%
from konlpy.tag import Okt
from wordcloud import WordCloud
from collections import Counter

# text 파일 읽어오기
#※※주소불러올때 \를 //로 바꾸어주기※※
blog_text = open('C://주소//blog_text.txt','rt', encoding='UTF-8').read()
#print(blog_text)

# csv 파일일때
# import pandas as pd
# blog_text = pd.read_csv('csv파일.csv',encoding='utf-8')
# blog_text = blog_text['형태소분석할 컬럼명']

# Okt 함수를 이용해 형태소 분석
okt = Okt()
line =[]

line = okt.pos(blog_text)

n_adj =[]
# 명사 또는 형용사인 단어만 n_adj에 넣어주기
for word, tag in line:
    if tag in ['Noun','Adjective']:
        n_adj.append(word)
# 명사 또는 형용사인 단어 및 2글자 이상인 단어 선택 시
# n_adj = [word for word, tag in line if tag in ['Noun','Adjective'] and len(word) > 1]

#제외할 단어 추가
stop_words = "상암맛집 입니다 있어서 입니다." #추가할 때 띄어쓰기로 추가해주기
stop_words = set(stop_words.split(' '))

n_adj = [word for word in n_adj if not word in stop_words]
print(n_adj)

#print(line)
#print(n_adj)

#가장 많이 나온 단어 100개 저장
counts = Counter(n_adj)
tags = counts.most_common(100)

# 이미지 추가(워드크라우드 모양 설정)
import numpy as np
from PIL import Image

mask = Image.new("RGBA",(2555,2275), (255,255,255)) #(2555,2575)는 사진 크기, (255,255,255)는 색을의미
image = Image.open('C://Users//user//주소//heart.png').convert("RGBA")
x,y = image.size
mask.paste(image,(0,0,x,y),image)
mask = np.array(mask)

###WordCloud(워드크라우드) 만들기###
#폰트지정
font='C://폰트주소//폰트이름.ttf'
word_cloud = WordCloud(font_path=font, background_color='black',max_font_size=400, mask=mask,colormap='prism').generate_from_frequencies(dict(tags))

# 사이즈 설정 및 화면에 출력
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
plt.imshow(word_cloud)
plt.axis('off')
#워드클라우드 사진으로 저장
#cloud.to_file('상암맛집_wc.png')
#또는
plt.savefig('상암맛집.png', bbox_inches='tight')
plt.show()
