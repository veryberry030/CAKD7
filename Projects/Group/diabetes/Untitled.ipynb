# %%
48.8
57.9
77.5
76.6
79.9
71.7

# %%
import pandas as pd
import numpy as np

filename = './06. 건강검진 및 예방접종.xlsx - 1.건강검진수진.csv'
data = pd.read_csv(filename)
data
# Out:
#     Unnamed: 0  구 분    Unnamed: 2   2014 Unnamed: 4   2015 Unnamed: 6   2016  \
# 0          NaN  NaN           NaN      n   분율(표준오차)      n   분율(표준오차)      n
# 1          NaN   전체         19세이상  5,018       58.6  5,105       61.3  5,832
# 2          NaN   전체  19세이상(표준화)2)  5,018       56.4  5,105       59.5  5,832
# 3          NaN   전체         연령(세)    NaN        NaN    NaN        NaN    NaN
# 4          NaN   전체         19-29    581       34.2    645       39.6    670
# 5          NaN   전체         30-39    862       48.8    698       54.6  1,039
# 6          NaN   전체         40-49    853       67.1    891       70.0  1,082
# 7          NaN   전체         50-59    962       72.3  1,057       71.7  1,052
# 8          NaN   전체         60-69    891       76.7    943       74.7    975
# 9          NaN   전체           70+    869       58.5    871       60.5  1,014
# 10         NaN   전체           NaN    NaN        NaN    NaN        NaN    NaN
# ...

# %%
df = pd.DataFrame({'건강검진율':['48.8', '57.9', '77.5','76.6','79.9','71.7']}, dtype = float, index = ['20대', '30대', '40대','50대','60대','70대 이상'])
df
# Out:
#         건강검진율
# 20대      48.8
# 30대      57.9
# 40대      77.5
# 50대      76.6
# 60대      79.9
# 70대 이상   71.7

# %%
df.to_csv('health_check_2020.csv')

# %%
from matplotlib import font_manager, rc

font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

df.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
ax = df.plot.bar(y='건강검진율', rot=45)

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [23], in <cell line: 1>()
# ----> 1 df.plot.bar[df[df['건강검진율']=='20대']].set_color('orange')
#
# TypeError: 'method' object is not subscriptable
