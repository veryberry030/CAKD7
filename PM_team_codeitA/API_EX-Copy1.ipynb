# %%
# 네이버 검색 API예제는 블로그를 비롯 전문자료까지 호출방법이 동일하므로 blog검색만 대표로 예제를 올렸습니다.
# 네이버 검색 Open API 예제 - 블로그 검색
import os
import sys
import urllib.request
client_id = "SK1lPVqqTrpKU_yKXRqV"
client_secret = "thimoG7DOl"

query = urllib.parse.quote(input("검색 :"))
#url = "https://openapi.naver.com/v1/search/blog?query=" + query # json 결과
url = "https://openapi.naver.com/v1/search/blog.xml?query=" + query # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# 검색 :코드잇
# ...

# %%
import warnings
warnings.filterwarnings('ignore')
from bs4 import BeautifulSoup

xml = response_body.decode('utf-8')
bs = BeautifulSoup(xml,'xml')
bs.get_text()
# Out:
# "Naver Open API - blog ::'코드잇'https://search.naver.comNaver Search ResultFri, 25 Nov 2022 11:23:50 +09003972110내돈내산 <b>코드잇</b> codeit 1년 수강 후기https://blog.naver.com/best8388/222631368600어쩌다 <b>코드잇</b>을 알게 되었고, 1개월만 들어보고 판단해보자 싶어서 1개월 결제했다. 머신 러닝 강좌가 꽤 괜찮아서 다른 것도 조금 수강해보다가 1개월이 지났다. * 2020년 11월 마침 <b>코드잇</b>에서 1년 멤버십을... 블라블라블로그blog.naver.com/best838820220125프로그래밍 코딩이란? <b>코드잇</b> 후기 인강으로 입문 독학하기https://blog.naver.com/lucky_box7/222801956260오늘은 온라인을 통해 코딩을 독학할 수 있는 사이트, <b>코드잇</b> 후기를 살펴보려고 합니다. 여러 온라인 코딩 교육 플랫폼이 있지만 <b>코드잇</b>은 구독 형태로 무제한 강의 시청이 가능한 코딩 교육 사이트입니다. 웹... Cwon&apos;s Lifeblog.naver.com/lucky_box720220706[교육] <b>코드잇</b> :: 국내 최초 코딩 멤버십, 코딩 독학은 <b>코드잇</b>으로https://blog.naver.com/lemonrosez/222742103147바로 <b>코드잇</b> <b>코드잇</b>은 코딩 구독 서비스로 어떤 코딩 강의라도 무제한으로 수강할 수 있는 국내 최초 코딩 멤버십이다. 온라인 코딩 강의로 혼자서 충분하게 코딩을 독학할 수 있는 강의들이 제공된다. 목표에... 꿈을꾸다blog.naver.com/lemonrosez20220522혜코뿌_ 대코캠 <b>코드잇</b> 4기 찐 활동 후기 (feat. 코알못, 코린이)https://blog.naver.com/lhh7040/222402359936수료 키트를 받고 작성하고 싶어서 
# ...

# %%
# 네이버 검색 API예제는 블로그를 비롯 전문자료까지 호출방법이 동일하므로 blog검색만 대표로 예제를 올렸습니다.
# 네이버 검색 Open API 예제 - 블로그 검색
import os
import sys
import urllib.request
client_id = "SK1lPVqqTrpKU_yKXRqV"
client_secret = "thimoG7DOl"

query = urllib.parse.quote(input("검색 질의"))
url = "https://openapi.naver.com/v1/search/blog?query=" + query # json 결과
#url = "https://openapi.naver.com/v1/search/blog.xml?query=" + query # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# 검색 질의빅데이터
# {
# 	"lastBuildDate":"Thu, 28 Jul 2022 10:44:29 +0900",
# 	"total":1144656,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"<b>빅데이터<\/b>전문가 준비를 위한 체계적인 방법",
# 			"link":"https:\/\/blog.naver.com\/nam8853nam?Redirect=Log&logNo=222802704648",
# 			"description":"그 중에서도 주목해 볼만한 분야가 바로 ‘<b>빅데이터<\/b>’ 라고 생각했어요. 기업이 이익을 창출하기... 이런 점들을 고려했을 때 1) 영업, 2) 컨설팅, 3) 제조 분야 모두 통틀어서 데이터 분석이 정말 중요한 부분을... ",
# 			"bloggername":"율맘 스토리",
# 			"bloggerlink":"https:\/\/blog.naver.com\/nam8853nam",
# 			"postdate":"20220707"
# 		},
# 		{
# 			"title":"<b>빅데이터<\/b>분석기사 실기 준비를 위한 학습루틴",
# 			"link":"https:\/\/blog.naver.com\/parkrapp?Redirect=Log&logNo=222753783578",
# 			"description":"안녕하세요, 오늘은 제가 도전한 <b>빅데이터<\/b>분석기사에 대한 정보를 많은 분과 나누고 싶어 이야기를... <b>빅데이터<\/b>를 이해하고 이를 분석, 수집, 저장 등의 시각화를 수행하는 실무자 역할을 하는 분석기사는... ",
# 			"bloggername":"황금빛 쭈롱월드",
# 			"bloggerlink":"https:\/\/blog.naver.com\/parkrapp",
# 			"postdate":"20220531"
# 		},
# 		{
# ...

# %% [markdown]
# #### Q. 네이버 웹문서에서 빅데이터에 대한 데이터를 가져와서 데이터프레임으로 출력하세요.

# %%
# 네이버 검색 API예제는 블로그를 비롯 전문자료까지 호출방법이 동일하므로 blog검색만 대표로 예제를 올렸습니다.
# 네이버 검색 Open API 예제 - 블로그 검색
import os
import sys
import urllib.request
client_id = "SK1lPVqqTrpKU_yKXRqV"
client_secret = "thimoG7DOl"

encText = urllib.parse.quote("코드잇")
url = "https://openapi.naver.com/v1/search/webkr.json?query="+encText # json 결과
#url = "https://openapi.naver.com/v1/search/webkr.xml?query=" +encText  # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# 	"lastBuildDate":"Fri, 25 Nov 2022 11:24:40 +0900",
# 	"total":27140,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"코딩, 쉬워질 때도 됐다 | <b>코드잇<\/b>",
# 			"link":"https:\/\/www.codeit.kr\/",
# 			"description":"월 9,900원으로 Python, JavaScript, HTML\/CSS 등 3,000개 이상 프로그래밍 강의를 배워보세요!"
# 		},
# 		{
# 			"title":"<b>코드잇<\/b> - 홈",
# 			"link":"https:\/\/www.facebook.com\/codeit.kr",
# 			"description":"최고의 코딩 교육을 모두에게! - 온라인 코딩 스쿨, <b>코드잇<\/b> 서울특별시 04538"
# 		},
# 		{
# 			"title":"<b>코드잇<\/b>(@codeit_kr) • Instagram 사진 및 동영상",
# 			"link":"https:\/\/www.instagram.com\/codeit_kr\/",
# 			"description":"팔로워 5,003명, 팔로잉 215명, 게시물 51개 - <b>코드잇<\/b>(@codeit_kr)님의 Instagram 사진 및 동영상 보기"
# 		},
# 		{
# 			"title":"<b>코드잇<\/b> - 나무위키",
# 			"link":"https:\/\/namu.wiki\/w\/%EC%BD%94%EB%93%9C%EC%9E%87",
# 			"description":"2017년 설립된 에듀테크(Edu-Tech) 스타트업 온라인 프로그래밍 교육 서비스를 제공하고 있다. 프로그래밍 교육에 최적화된 학습 플랫폼과 자제제작 콘텐츠 제공이 특징이다."
# 		},
# 		{
# 			"title":"<b>코드잇<\/b> 소개",
# ...

# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd

df = pd.read_json(response_body.decode('utf-8'))
df
# Out:
#                      lastBuildDate  total  start  display  \
# 0  Fri, 25 Nov 2022 11:24:40 +0900  27140      1       10
# 1  Fri, 25 Nov 2022 11:24:40 +0900  27140      1       10
# 2  Fri, 25 Nov 2022 11:24:40 +0900  27140      1       10
# 3  Fri, 25 Nov 2022 11:24:40 +0900  27140      1       10
# 4  Fri, 25 Nov 2022 11:24:40 +0900  27140      1       10
# 5  Fri, 25 Nov 2022 11:24:40 +0900  27140      1       10
# 6  Fri, 25 Nov 2022 11:24:40 +0900  27140      1       10
# 7  Fri, 25 Nov 2022 11:24:40 +0900  27140      1       10
# 8  Fri, 25 Nov 2022 11:24:40 +0900  27140      1       10
# 9  Fri, 25 Nov 2022 11:24:40 +0900  27140      1       10
#
#                                                items
# 0  {'title': '코딩, 쉬워질 때도 됐다 | <b>코드잇</b>', 'link'...
# 1  {'title': '<b>코드잇</b> - 홈', 'link': 'https://w...
# 2  {'title': '<b>코드잇</b>(@codeit_kr) • Instagram ...
# 3  {'title': '<b>코드잇</b> - 나무위키', 'link': 'https:...
# 4  {'title': '<b>코드잇</b> 소개', 'link': 'https://ab...
# ...

# %%
import os
import sys
import urllib.request
client_id = "SK1lPVqqTrpKU_yKXRqV"
client_secret = "thimoG7DOl"
encText = urllib.parse.quote("코드잇")
url = 'https://openapi.naver.com/v1/search/webkr.json?query='+encText # json 결과
# url = "https://openapi.naver.com/v1/search/webkr.json?query=" + encText # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# 	"lastBuildDate":"Fri, 25 Nov 2022 11:24:56 +0900",
# 	"total":26964,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"<b>코드잇<\/b> - 홈",
# 			"link":"https:\/\/www.facebook.com\/codeit.kr",
# 			"description":"최고의 코딩 교육을 모두에게! - 온라인 코딩 스쿨, <b>코드잇<\/b> 서울특별시 04538"
# 		},
# 		{
# 			"title":"<b>코드잇<\/b>(@codeit_kr) • Instagram 사진 및 동영상",
# 			"link":"https:\/\/www.instagram.com\/codeit_kr\/",
# 			"description":"팔로워 5,003명, 팔로잉 215명, 게시물 51개 - <b>코드잇<\/b>(@codeit_kr)님의 Instagram 사진 및 동영상 보기"
# 		},
# 		{
# 			"title":"<b>코드잇<\/b> - 나무위키",
# 			"link":"https:\/\/namu.wiki\/w\/%EC%BD%94%EB%93%9C%EC%9E%87",
# 			"description":"2017년 설립된 에듀테크(Edu-Tech) 스타트업 온라인 프로그래밍 교육 서비스를 제공하고 있다. 프로그래밍 교육에 최적화된 학습 플랫폼과 자제제작 콘텐츠 제공이 특징이다."
# 		},
# 		{
# 			"title":"<b>코드잇<\/b> 소개",
# 			"link":"https:\/\/about.codeit.com\/ko\/",
# ...

# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
df = pd.read_json(response_body.decode('utf-8'))
df
# Out:
#                      lastBuildDate  total  start  display  \
# 0  Fri, 25 Nov 2022 11:24:56 +0900  26964      1       10
# 1  Fri, 25 Nov 2022 11:24:56 +0900  26964      1       10
# 2  Fri, 25 Nov 2022 11:24:56 +0900  26964      1       10
# 3  Fri, 25 Nov 2022 11:24:56 +0900  26964      1       10
# 4  Fri, 25 Nov 2022 11:24:56 +0900  26964      1       10
# 5  Fri, 25 Nov 2022 11:24:56 +0900  26964      1       10
# 6  Fri, 25 Nov 2022 11:24:56 +0900  26964      1       10
# 7  Fri, 25 Nov 2022 11:24:56 +0900  26964      1       10
# 8  Fri, 25 Nov 2022 11:24:56 +0900  26964      1       10
# 9  Fri, 25 Nov 2022 11:24:56 +0900  26964      1       10
#
#                                                items
# 0  {'title': '<b>코드잇</b> - 홈', 'link': 'https://w...
# 1  {'title': '<b>코드잇</b>(@codeit_kr) • Instagram ...
# 2  {'title': '<b>코드잇</b> - 나무위키', 'link': 'https:...
# 3  {'title': '<b>코드잇</b> 소개', 'link': 'https://ab...
# 4  {'title': '<b>코드잇</b> - 기업정보 - THE VC', 'link'...
# ...

# %% [markdown]
# #### 과제 0728_1
#
# 웹문서에서 빅데이터에 대한 의미있는 정보로 구성된 데이터프레임을 출력하세요

# %%
import os
import sys
import urllib.request
import warnings
warnings.filterwarnings('ignore')
import pandas as pd

client_id = "SK1lPVqqTrpKU_yKXRqV"
client_secret = "thimoG7DOl"
encText = urllib.parse.quote("코드잇")
url = 'https://openapi.naver.com/v1/search/webkr.json?query='+encText # json 결과
# url = "https://openapi.naver.com/v1/search/webkr.json?query=" + encText # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    #print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
    
df = pd.read_json(response_body.decode('utf-8'))
df
# Out:
#                      lastBuildDate  total  start  display  \
# 0  Fri, 25 Nov 2022 11:25:13 +0900  26958      1       10
# 1  Fri, 25 Nov 2022 11:25:13 +0900  26958      1       10
# 2  Fri, 25 Nov 2022 11:25:13 +0900  26958      1       10
# 3  Fri, 25 Nov 2022 11:25:13 +0900  26958      1       10
# 4  Fri, 25 Nov 2022 11:25:13 +0900  26958      1       10
# 5  Fri, 25 Nov 2022 11:25:13 +0900  26958      1       10
# 6  Fri, 25 Nov 2022 11:25:13 +0900  26958      1       10
# 7  Fri, 25 Nov 2022 11:25:13 +0900  26958      1       10
# 8  Fri, 25 Nov 2022 11:25:13 +0900  26958      1       10
# 9  Fri, 25 Nov 2022 11:25:13 +0900  26958      1       10
#
#                                                items
# 0  {'title': '<b>코드잇</b> - 홈', 'link': 'https://w...
# 1  {'title': '<b>코드잇</b>(@codeit_kr) • Instagram ...
# 2  {'title': '<b>코드잇</b> - 나무위키', 'link': 'https:...
# 3  {'title': '<b>코드잇</b> 소개', 'link': 'https://ab...
# 4  {'title': '<b>코드잇</b> - 기업정보 - THE VC', 'link'...
# ...

# %%
df.drop(['lastBuildDate','total','start','display'],axis=1,inplace=True)
df
# Out:
#                                                items
# 0  {'title': '<b>코드잇</b> - 홈', 'link': 'https://w...
# 1  {'title': '<b>코드잇</b>(@codeit_kr) • Instagram ...
# 2  {'title': '<b>코드잇</b> - 나무위키', 'link': 'https:...
# 3  {'title': '<b>코드잇</b> 소개', 'link': 'https://ab...
# 4  {'title': '<b>코드잇</b> - 기업정보 - THE VC', 'link'...
# 5  {'title': '<b>코드잇</b>(<b>코드잇</b>) 채용 정보 - 로켓펀치...
# 6  {'title': '<b>코드잇</b>(codeit) 수강 1년차가 말하는 <b>코...
# 7  {'title': '<b>코드잇</b> 비즈니스 교육을 시작하세요', 'link':...
# 8  {'title': '<b>코드잇</b> &lt;데이터 사이언스 입문&gt; 수강하고...
# 9  {'title': '로그인 | <b>코드잇</b>', 'link': 'https:/...

# %%
import re
df_items = df['items'].to_list()

for item in df_items:
    df_items = str(df_items)
    df_items = re.sub('[^\w]',' ',df_items)
    df_items = re.sub(r'<[a-z]>',' ',df_items)
    df_items = re.sub('<br></br>',' ',df_items)
    
df_items
# Out:
# '   title     b 코드잇  b    홈    link    https   www facebook com codeit kr    description    최고의 코딩 교육을 모두에게    온라인 코딩 스쿨   b 코드잇  b  서울특별시 04538      title     b 코드잇  b   codeit_kr    Instagram 사진 및 동영상    link    https   www instagram com codeit_kr     description    팔로워 5 003명  팔로잉 215명  게시물 51개    b 코드잇  b   codeit_kr 님의 Instagram 사진 및 동영상 보기      title     b 코드잇  b    나무위키    link    https   namu wiki w  EC BD 94 EB 93 9C EC 9E 87    description    2017년 설립된 에듀테크 Edu Tech  스타트업 온라인 프로그래밍 교육 서비스를 제공하고 있다  프로그래밍 교육에 최적화된 학습 플랫폼과 자제제작 콘텐츠 제공이 특징이다       title     b 코드잇  b  소개    link    https   about codeit com ko     description    있도록  b 코드잇  b 이 함께 하겠습니다  Press  amp  News 온라인 코딩 교육   b 코드잇  b    100억 시리즈 B 투자 유치    교육   b 코드잇  b    B2B 고객사 수 늘어 시민일보  b 코드잇  b   2021 중기부  아기유니콘  선정 기념 프로모션 진행          title     b 코드잇  b    기업정보   THE VC    link    https   thevc kr codeit    description     b 코드잇  b  Codeit   스타트업   대표  이윤수  강영훈 의 투자 유치 2건 최근 단계 Series B   특허 1건  최신 뉴스 61건  고용  재무 
# ...

# %% [markdown]
# #### 과제 0728_2
#
# 뉴스, 영화, 쇼핑, 지식인, 카페글에서 적합한 주제에 대한 데이터를 가져와서 데이터프레임으로 출력하세요.

# %%
# 카페글
import os
import sys
import urllib.request
import warnings
warnings.filterwarnings('ignore')
import pandas as pd

client_id = "SK1lPVqqTrpKU_yKXRqV"
client_secret = "thimoG7DOl"
encText = urllib.parse.quote("빅데이터")
url = 'https://openapi.naver.com/v1/search/cafearticle.json?query='+encText # json 결과
# url = "https://openapi.naver.com/v1/search/cafearticle.json?query=" + encText # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    #print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
    
df = pd.read_json(response_body.decode('utf-8'))
df.drop(['lastBuildDate','total','start','display'],axis=1,inplace=True)
df
# Out:
#                                                items
# 0  {'title': '2022 <b>빅데이터</b> 분석기사 시험일정 + 시험과목 필...
# 1  {'title': '<b>빅데이터</b>분석기사 자격증 정보 여기서 확인해보세요',...
# 2  {'title': '<b>빅데이터</b> 취업..', 'link': 'http://...
# 3  {'title': '<b>빅데이터</b>분석기사 응시자격 학점은행제로 미래유망직업 ...
# 4  {'title': '<b>빅데이터</b>분석기사인강 합격으로 가는 지름길!', 'l...
# 5  {'title': '<b>빅데이터</b> 분석가 되려면 어떻게 해야 하나요?', '...
# 6  {'title': '<b>빅데이터</b> 자격증도 있네요?', 'link': 'ht...
# 7  {'title': '<b>빅데이터</b> 분석기사 시험 응시자격/시험일정 등 모두 ...
# 8  {'title': '<b>빅데이터</b>관련 및 취업관련 질문입니다.', 'link...
# 9  {'title': '<b>빅데이터</b>강의 R프로그래밍으로 취뽀하자!', 'lin...

# %%
# 지식인
import os
import sys
import urllib.request
import warnings
warnings.filterwarnings('ignore')
import pandas as pd

client_id = "SK1lPVqqTrpKU_yKXRqV"
client_secret = "thimoG7DOl"
encText = urllib.parse.quote("집에가고싶어요")
url = 'https://openapi.naver.com/v1/search/kin.json?query='+encText # json 결과
# url = "https://openapi.naver.com/v1/search/kin.json?query=" + encText # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    #print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
    
df = pd.read_json(response_body.decode('utf-8'))
df.drop(['lastBuildDate','total','start','display'],axis=1,inplace=True)
df
# Out:
#                                                items
# 0  {'title': '집에 있는데 <b>집에 가고 싶어요</b>', 'link': '...
# 1  {'title': '남자친구가 만나면 빨리 <b>집에 가고싶어</b>해요', 'li...
# 2  {'title': '<b>집에 가고 싶어</b>..', 'link': 'https:...
# 3  {'title': '친구<b>집에 가고싶어요</b>', 'link': 'https:...
# 4  {'title': '<b>집에 가고 싶어요</b>', 'link': 'https:/...
# 5  {'title': '<b>집에 가고싶어요</b>', 'link': 'https://...
# 6  {'title': '<b>집에 가고 싶어요</b>', 'link': 'https:/...
# 7  {'title': '집에 있는데도 <b>집에 가고 싶어요</b>...', 'link...
# 8  {'title': '<b>집에 가고 싶어요</b>', 'link': 'https:/...
# 9  {'title': '안녕하세요 <b>집에 가고 싶어요</b>', 'link': 'h...

# %%
# 쇼핑
import os
import sys
import urllib.request
import warnings
warnings.filterwarnings('ignore')
import pandas as pd

client_id = "SK1lPVqqTrpKU_yKXRqV"
client_secret = "thimoG7DOl"
encText = urllib.parse.quote("링티")
url = 'https://openapi.naver.com/v1/search/shop.json?query='+encText # json 결과
# url = "https://openapi.naver.com/v1/search/shop.json?query=" + encText # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    #print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
    
df = pd.read_json(response_body.decode('utf-8'))
df.drop(['lastBuildDate','total','start','display'],axis=1,inplace=True)
df
# Out:
#                                                items
# 0  {'title': '<b>링티</b> 제로 복숭아맛 500ml', 'link': '...
# 1  {'title': '<b>링티</b> 액티브 11g x 10포', 'link': '...
# 2  {'title': '<b>링티</b> 레몬맛 11.6g x 10포', 'link':...
# 3  {'title': '<b>링티</b> 복숭아맛 11.65g x 10포', 'link...
# 4  {'title': '<b>링티</b> 플러스21 11.82g x 10포', 'lin...
# 5  {'title': '[<b>링티</b>] <b>링티</b> 액티브 2.0 10박스+...
# 6  {'title': '<b>링티</b> 액티브2.0 11g x 10포', 'link'...
# 7  {'title': '<b>링티</b> <b>링티</b>효능 레몬맛,복숭아맛', 'l...
# 8  {'title': '[약국용] <b>링티</b>플러스22 10포 / 3개 이상 구매...
# 9  {'title': '<b>링티</b> 제로 복숭아맛 500ml 12개 24개 마시는...

# %% [markdown]
# #### 과제 0728_3
#
# #### 아래사항에 유의하여 OpenWeatherMap 날씨정보를 웹 API로 가져와서 출력하세요
# * https://openweathermap.org/api 사이트에서 Current Weather data에 대한 API doc 내용을 파악
# * 개발자 등록을 하고 API 키 발급 받음(https://home.openweathermap.org/users/sign_up)
# * New Account 등록 후 API Keys라는 탭에서 API Key 확인 가능
# * 기본적으로 유료 사이트이지만 현재 날씨, 5일까지의 날씨는 무료로 사용할 수 있음(단 1분에 60번만 호출 가능)
# * 서울, 도쿄, 뉴욕의 날씨를 가져오는 프로그램 작성(text로 가져와서 json으로 변환하여 일차 출력)
#   - cities = ["Seoul,KR", "Tokyo,JP", "New York,US"]
#   - 가져올 정보 : 도시별 날씨(description), 최저 기온(temp_min), 최고 기온(temp_max), 습도(humidity), 기압(pressure), 풍속(speed)
#   - 기온 데이터는 켈빈 온도로 되어 있으며 섭씨 온도로 변환해서 출력
# * json 포멧으로 출력 데이터를 아래와 같이 가독성 있게 출력(소수점 2번째에서 반올림 처리)

# %%
+ 도시 = Seoul
| 날씨 = broken clouds
| 최저 기온 = -1.0 2
| 최고 기온 = 2.0 2
| 습도 = 74
| 기압 = 1023
| 풍속 = 0.5

# %%
# seoul
import os
import sys
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
from urllib.request import Request,urlopen
from urllib.parse import urlencode,quote_plus
import pandas as pd
import json

#cities = ["Seoul,KR", "Tokyo,JP", "New York,US"]

appid = '50f17e8da89991589645f38cea832caf'

city_name = 'Seoul,KR'
#city_name = 'Tokyo,JP'
#city_name = 'New%20York,US'

url = 'https://api.openweathermap.org/data/2.5/weather?' 
params = f'q={city_name}&appid={appid}'
query = url + params
print(query)

    
request = Request(query)
request.get_method = lambda:'GET'
response_body = urlopen(request).read()
print(response_body)

weather = json.loads(response_body.decode('utf-8'))
weather
# Out:
# https://api.openweathermap.org/data/2.5/weather?q=Seoul,KR&appid=50f17e8da89991589645f38cea832caf
# b'{"coord":{"lon":126.9778,"lat":37.5683},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04n"}],"base":"stations","main":{"temp":302.34,"feels_like":305.36,"temp_min":299.84,"temp_max":303.81,"pressure":1010,"humidity":65},"visibility":10000,"wind":{"speed":2.06,"deg":270},"clouds":{"all":75},"dt":1659007345,"sys":{"type":1,"id":8105,"country":"KR","sunrise":1658953929,"sunset":1659005087},"timezone":32400,"id":1835848,"name":"Seoul","cod":200}'
# {'coord': {'lon': 126.9778, 'lat': 37.5683},
#  'weather': [{'id': 803,
#    'main': 'Clouds',
#    'description': 'broken clouds',
#    'icon': '04n'}],
#  'base': 'stations',
#  'main': {'temp': 302.34,
#   'feels_like': 305.36,
#   'temp_min': 299.84,
#   'temp_max': 303.81,
#   'pressure': 1010,
#   'humidity': 65},
#  'visibility': 10000,
#  'wind': {'speed': 2.06, 'deg': 270},
#  'clouds': {'all': 75},
# ...

# %%
name = weather['name']
description = weather['weather'][0]['description']
temp_min = weather['main']['temp_min']- 273.15
temp_min = int(temp_min)
temp_max = weather['main']['temp_max']- 273.15
temp_max = int(temp_max)
humidity = weather['main']['humidity']
pressure = weather['main']['pressure']
speed = weather['wind']['speed']
print(name)
print(description)
print(temp_min)
print(temp_max)
print(humidity)
print(pressure)
print(speed)
# Out:
# Seoul
# broken clouds
# 26
# 30
# 65
# 1010
# 2.06

# %%
print(f'+ 도시 = {name}')
print(f'| 날씨 = {description}')
print(f'| 최저 기온 = {temp_min}')
print(f'| 최고 기온 = {temp_max}')
print(f'| 습도 = {humidity}')
print(f'| 기압 = {pressure}')
print(f'| 풍속 = {speed}')
# Out:
# + 도시 = Seoul
# | 날씨 = broken clouds
# | 최저 기온 = 26
# | 최고 기온 = 30
# | 습도 = 65
# | 기압 = 1010
# | 풍속 = 2.06

# %%
# tokyo
import os
import sys
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
from urllib.request import Request,urlopen
from urllib.parse import urlencode,quote_plus
import pandas as pd
import json

#cities = ["Seoul,KR", "Tokyo,JP", "New York,US"]

appid = '50f17e8da89991589645f38cea832caf'

#city_name = 'Seoul,KR'
city_name = 'Tokyo,JP'
#city_name = 'New%20York,US'

url = 'https://api.openweathermap.org/data/2.5/weather?' 
params = f'q={city_name}&appid={appid}'
query = url + params
print(query)

    
request = Request(query)
request.get_method = lambda:'GET'
response_body = urlopen(request).read()
print(response_body)

weather = json.loads(response_body.decode('utf-8'))
weather
# Out:
# https://api.openweathermap.org/data/2.5/weather?q=Tokyo,JP&appid=50f17e8da89991589645f38cea832caf
# b'{"coord":{"lon":139.6917,"lat":35.6895},"weather":[{"id":501,"main":"Rain","description":"moderate rain","icon":"10n"}],"base":"stations","main":{"temp":301.57,"feels_like":305.97,"temp_min":297.62,"temp_max":303.16,"pressure":1016,"humidity":78},"visibility":10000,"wind":{"speed":6.17,"deg":200},"rain":{"1h":2.05},"clouds":{"all":75},"dt":1659008478,"sys":{"type":2,"id":2038398,"country":"JP","sunrise":1658951135,"sunset":1659001779},"timezone":32400,"id":1850144,"name":"Tokyo","cod":200}'
# {'coord': {'lon': 139.6917, 'lat': 35.6895},
#  'weather': [{'id': 501,
#    'main': 'Rain',
#    'description': 'moderate rain',
#    'icon': '10n'}],
#  'base': 'stations',
#  'main': {'temp': 301.57,
#   'feels_like': 305.97,
#   'temp_min': 297.62,
#   'temp_max': 303.16,
#   'pressure': 1016,
#   'humidity': 78},
#  'visibility': 10000,
#  'wind': {'speed': 6.17, 'deg': 200},
# ...

# %%
name = weather['name']
description = weather['weather'][0]['description']
temp_min = weather['main']['temp_min']- 273.15
temp_min = int(temp_min)
temp_max = weather['main']['temp_max']- 273.15
temp_max = int(temp_max)
humidity = weather['main']['humidity']
pressure = weather['main']['pressure']
speed = weather['wind']['speed']

print(f'+ 도시 = {name}')
print(f'| 날씨 = {description}')
print(f'| 최저 기온 = {temp_min}')
print(f'| 최고 기온 = {temp_max}')
print(f'| 습도 = {humidity}')
print(f'| 기압 = {pressure}')
print(f'| 풍속 = {speed}')
# Out:
# + 도시 = Tokyo
# | 날씨 = moderate rain
# | 최저 기온 = 24
# | 최고 기온 = 30
# | 습도 = 78
# | 기압 = 1016
# | 풍속 = 6.17

# %%
# tokyo
import os
import sys
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
from urllib.request import Request,urlopen
from urllib.parse import urlencode,quote_plus
import pandas as pd
import json

#cities = ["Seoul,KR", "Tokyo,JP", "New York,US"]

appid = '50f17e8da89991589645f38cea832caf'

#city_name = 'Seoul,KR'
#city_name = 'Tokyo,JP'
city_name = 'New%20York,US'

url = 'https://api.openweathermap.org/data/2.5/weather?' 
params = f'q={city_name}&appid={appid}'
query = url + params
print(query)

    
request = Request(query)
request.get_method = lambda:'GET'
response_body = urlopen(request).read()
print(response_body)

weather = json.loads(response_body.decode('utf-8'))
weather
# Out:
# https://api.openweathermap.org/data/2.5/weather?q=New%20York,US&appid=50f17e8da89991589645f38cea832caf
# b'{"coord":{"lon":-74.006,"lat":40.7143},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}],"base":"stations","main":{"temp":296.88,"feels_like":297.63,"temp_min":295.79,"temp_max":297.8,"pressure":1011,"humidity":89},"visibility":10000,"wind":{"speed":3.6,"deg":180},"clouds":{"all":75},"dt":1659008751,"sys":{"type":2,"id":2039034,"country":"US","sunrise":1659001728,"sunset":1659053760},"timezone":-14400,"id":5128581,"name":"New York","cod":200}'
# {'coord': {'lon': -74.006, 'lat': 40.7143},
#  'weather': [{'id': 803,
#    'main': 'Clouds',
#    'description': 'broken clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 296.88,
#   'feels_like': 297.63,
#   'temp_min': 295.79,
#   'temp_max': 297.8,
#   'pressure': 1011,
#   'humidity': 89},
#  'visibility': 10000,
#  'wind': {'speed': 3.6, 'deg': 180},
#  'clouds': {'all': 75},
# ...

# %%
name = weather['name']
description = weather['weather'][0]['description']
temp_min = weather['main']['temp_min']- 273.15
temp_min = int(temp_min)
temp_max = weather['main']['temp_max']- 273.15
temp_max = int(temp_max)
humidity = weather['main']['humidity']
pressure = weather['main']['pressure']
speed = weather['wind']['speed']

print(f'+ 도시 = {name}')
print(f'| 날씨 = {description}')
print(f'| 최저 기온 = {temp_min}')
print(f'| 최고 기온 = {temp_max}')
print(f'| 습도 = {humidity}')
print(f'| 기압 = {pressure}')
print(f'| 풍속 = {speed}')
# Out:
# + 도시 = New York
# | 날씨 = broken clouds
# | 최저 기온 = 22
# | 최고 기온 = 24
# | 습도 = 89
# | 기압 = 1011
# | 풍속 = 3.6

# %% [markdown]
# ### 공공데이터 api

# %%
#### 상가 업소 정보

# %%
from urllib.request import Request,urlopen
from urllib.parse import urlencode,quote_plus
import pandas as pd
import json

skey = 'EbwPIaTQ%2Bn53RTCBMoZUvZYQ6Md6hF85t6GkF1SQn4IQbT8lXzCKZPS%2BLvYw4mTX2ytwazyZbfe6SzIXv3YZKA%3D%3D'

res_id = 'storezone'
stype = 'json'

url = 'http://apis.data.go.kr/B553077/api/open/sdsc2/baroApi'
params = f'?ServiceKey={skey}&type={stype}&resId={res_id}&'+urlencode({quote_plus('key'):'9174'})
query = url + params
print(query)

request = Request(query)
request.get_method = lambda:'GET'
response_body = urlopen(request).read()
print(response_body)

response_dict = json.loads(response_body.decode('utf-8'))
items = response_dict['body']['items']

df = pd.DataFrame(items)
df
# Out:
# http://apis.data.go.kr/B553077/api/open/sdsc2/baroApi?ServiceKey=EbwPIaTQ%2Bn53RTCBMoZUvZYQ6Md6hF85t6GkF1SQn4IQbT8lXzCKZPS%2BLvYw4mTX2ytwazyZbfe6SzIXv3YZKA%3D%3D&type=json&resId=storezone&key=9174
# ...

# %%
from urllib.request import Request,urlopen
from urllib.parse import urlencode,quote_plus
import pandas as pd
import json


def baro_api(skey,res_id,encode):
    stype = 'json'
    url = 'http://apis.data.go.kr/B553077/api/open/sdsc2/baroApi'
    params = f'?ServiceKey={skey}&type={stype}&resId={res_id}&'+encode
    query = url + params
    
    request = Request(query)
    request.get_method = lambda:'GET'
    response_body = urlopen(request).read()
    
    response_dict = json.loads(response_body.decode('utf-8'))
    items = response_dict['body']['items']
    df = pd.DataFrame(items)
    return df

# %% [markdown]
# ### 상권조회

# %% [markdown]
# #### 지정 상권 조회

# %%
skey = 'EbwPIaTQ%2Bn53RTCBMoZUvZYQ6Md6hF85t6GkF1SQn4IQbT8lXzCKZPS%2BLvYw4mTX2ytwazyZbfe6SzIXv3YZKA%3D%3D'
res_id = 'storezone'
encode = urlencode({quote_plus('key'):'9193'})

baro_api(skey,res_id,encode)
# Out:
#    trarNo  mainTrarNm ctprvnCd ctprvnNm signguCd signguNm  trarArea  coordNum  \
# 0    9193  동대문역사문화공원역       11    서울특별시    11140       중구     79167        17
#
#                                               coords      stdrDt
# 0  MULTIPOLYGON (((127.00304244009 37.56673071604...  2021-06-30

# %% [markdown]
# #### 반경 내 상권 조회

# %%
encode = urlencode({quote_plus('catId'):'radius',
                   quote_plus('radius'):'500',
                   quote_plus('cx'):'127.004528',
                   quote_plus('cy'):'37.567538'})
baro_api(skey,res_id,encode)
# Out:
#    trarNo  mainTrarNm ctprvnCd ctprvnNm signguCd signguNm  trarArea  coordNum  \
# 0    9170     동대문시장_1       11    서울특별시    11110      종로구     75046        13
# 1    9180     종로5가역_1       11    서울특별시    11110      종로구     44881         9
# 2    9192     동대문시장_2       11    서울특별시    11140       중구     60995        18
# 3    9193  동대문역사문화공원역       11    서울특별시    11140       중구     79167        17
# 4    9206      을지로4가역       11    서울특별시    11140       중구     81565         9
#
#                                               coords      stdrDt
# 0  MULTIPOLYGON (((127.00616674831 37.57097429301...  2021-06-30
# 1  MULTIPOLYGON (((127.001579474423 37.5708212220...  2021-06-30
# 2  MULTIPOLYGON (((127.006693001676 37.5694470928...  2021-06-30
# 3  MULTIPOLYGON (((127.00304244009 37.56673071604...  2021-06-30
# 4  MULTIPOLYGON (((126.998050690253 37.5686092455...  2021-06-30

# %% [markdown]
# #### 과제0728_4
# 사각형 내 상권 조회

# %%
skey = 'EbwPIaTQ%2Bn53RTCBMoZUvZYQ6Md6hF85t6GkF1SQn4IQbT8lXzCKZPS%2BLvYw4mTX2ytwazyZbfe6SzIXv3YZKA%3D%3D'
res_id = 'storezone'
encode = urlencode({quote_plus('key'):'9193'})

res_id = 'store'

encode = urlencode({quote_plus('catId'):'rectangle',
                   quote_plus('minx'):'126.978020',
                   quote_plus('miny'):'37.557825',
                   quote_plus('maxx'):'126.987732',
                   quote_plus('maxy'):'37.562022'})

baro_api(skey,res_id,encode)
# Out:
#      bizesId   bizesNm    brchNm indsLclsCd indsLclsNm indsMclsCd  \
# 0   11054686       끌로에     신세계본점          D         소매        D06
# 1   11761713      블랙앤쿡                    Q         음식        Q01
# 2   11768677       플로팅                    Q         음식        Q09
# 3   11792650  LG전자베스트샵     신세계본점          D         소매        D12
# 4   11820077        대명                    D         소매        D06
# 5   11856641       포르테                    D         소매        D05
# 6   11856701        선물                    D         소매        D05
# 7   11868159       스토리                    D         소매        D05
# 8   11892911      누리공방                    D         소매        D05
# 9   11893929         수                    D         소매        D05
# 10  11899512     니키하우스                    D         소매        D05
# 11  11901335        동성                    D         소매        D17
# 12  11902172       꿈아이                    D         소매        D05
# ...

# %% [markdown]
# #### 과제0728_5
# 행정 단위 상권 조회

# %%
res_id = 'storezone'

encode = urlencode({quote_plus('catId'):'dong',
                   quote_plus('divId'):'adongCd', # divId: 구분 => ctprvnCd : 광역시도
                   quote_plus('key'):'1168069000'}) # key : 행정구역
baro_api(skey,res_id,encode)
# Out:
#    trarNo mainTrarNm ctprvnCd ctprvnNm signguCd signguNm  trarArea  coordNum  \
# 0    9324      포이사거리       11    서울특별시    11680      강남구     14033        33
#
#                                               coords      stdrDt
# 0  MULTIPOLYGON (((127.044811833677 37.4781705036...  2021-06-30

# %% [markdown]
# #### 상가 업소 조회
#
# - 행정동 단위 상가업소 조회

# %%
res_id = 'store'

encode = urlencode({quote_plus('catId'):'dong',
                   quote_plus('divId'):'ctprvnCd', # divId: 구분 => ctprvnCd : 광역시도
                   quote_plus('key'):'11'}) # key : 행정구역
baro_api(skey,res_id,encode)
# Out:
#      bizesId     bizesNm  brchNm indsLclsCd indsLclsNm indsMclsCd  \
# 0   10001387      이음스튜디오                  D         소매        D18
# 1   10004623      이철헤어커커    상계역점          F      생활서비스        F01
# 2   10016187        일조산업                  D         소매        D07
# 3   10030788      장안순대국밥                  Q         음식        Q10
# 4   10031349         장어야    동자동점          Q         음식        Q01
# 5   10031436        장어천국                  Q         음식        Q01
# 6   10034303        재건공조                  D         소매        D07
# 7   10034977        재진패션                  D         소매        D05
# 8   10038561   전자랜드프라이스킹     은평점          D         소매        D12
# 9   10041487         정관장   서대문역점          D         소매        D03
# 10  10041503         정관장   남부법원점          D         소매        D10
# 11  10050747       제시카키친  이대하늬솔점          Q         음식        Q06
# 12  10056742      제일전기조명                  D         소매        D07
# ...
